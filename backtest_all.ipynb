# %%
import pandas as pd
import numpy as np
import datetime

def load_data(spy_file, vix_file):
    df_spy = pd.read_csv(spy_file, parse_dates=["DateTime"])
    df_spy.sort_values("DateTime", inplace=True)
    df_spy.set_index("DateTime", inplace=True)
    df_spy = df_spy.between_time("09:30", "16:00")

    df_vix = pd.read_csv(vix_file, parse_dates=["DateTime"])
    df_vix.sort_values("DateTime", inplace=True)
    df_vix.set_index("DateTime", inplace=True)
    df_vix = df_vix.between_time("09:30", "16:00")

    start = max(df_spy.index.min(), df_vix.index.min())
    end = min(df_spy.index.max(), df_vix.index.max())
    df_spy = df_spy.loc[(df_spy.index >= start) & (df_spy.index <= end)]
    df_vix = df_vix.loc[(df_vix.index >= start) & (df_vix.index <= end)]

    df_vix = df_vix.rename(
        columns={
            "Open": "Open_vix",
            "High": "High_vix",
            "Low":  "Low_vix",
            "Close":"Close_vix"
        }
    )

    df_merged = pd.merge_asof(
        df_spy.sort_index(),
        df_vix.sort_index(),
        left_index=True,
        right_index=True,
        direction='forward'
    )
    return df_merged

def compute_14day_abs_moves(df):
    df["TradeDate"] = df.index.date
    df["TimeOfDay"] = df.index.time
    df["HHMM"] = df.index.strftime("%H:%M")
    open9_30 = df[df["HHMM"]=="09:30"].groupby("TradeDate")["Open"].first().rename("Open9_30")
    df = df.join(open9_30, on="TradeDate")
    df["pct_move_from_open"] = (df["Close"] / df["Open9_30"]) - 1
    df["abs_move"] = df["pct_move_from_open"].abs()
    return df

def rolling_14day_average_move(df):
    df = df.sort_values(["TradeDate","TimeOfDay"]).copy()
    df["avg_move_14d"] = np.nan
    groups = dict(tuple(df.groupby("TimeOfDay")))
    for tod, subdf in groups.items():
        subdf = subdf.sort_values("TradeDate")
        subdf["avg_move_14d"] = subdf["abs_move"].rolling(14, min_periods=14).mean()
        groups[tod] = subdf
    df_final = pd.concat(groups.values(), axis=0)
    df_final = df_final.sort_index()
    return df_final

def compute_noise_boundaries(df):
    df["HHMM"] = df.index.strftime("%H:%M")
    df["PrevClose"] = df.groupby("TradeDate")["Close"].shift(1)
    is_9_30 = (df["HHMM"] == "09:30")
    df.loc[is_9_30, "PrevClose"] = df.loc[is_9_30, "Close"].shift(1)
    df["PrevClose"] = df["PrevClose"].ffill()
    df["RefPriceMax"] = df[["Open9_30","PrevClose"]].max(axis=1)
    df["RefPriceMin"] = df[["Open9_30","PrevClose"]].min(axis=1)
    df["UpperBound"] = df["RefPriceMax"] * (1 + df["avg_move_14d"].fillna(0.0))
    df["LowerBound"] = df["RefPriceMin"] * (1 - df["avg_move_14d"].fillna(0.0))
    return df

def compute_vwap(df):
    df["cum_pv"] = 0.0
    df["cum_vol"] = 0.0

    def calc_cumpv(group):
        return (group["Close"] * group["Volume"]).cumsum()
    def calc_cumvol(group):
        return group["Volume"].cumsum()

    group_obj = df.groupby("TradeDate", group_keys=False)
    cum_pv_series = group_obj.apply(calc_cumpv)
    cum_vol_series = group_obj.apply(calc_cumvol)

    df["cum_pv"] = cum_pv_series
    df["cum_vol"] = cum_vol_series
    df["vwap"] = df["cum_pv"] / df["cum_vol"]
    return df

def compute_daily_volatility(df, n_days=14, target_vol=0.02):
    daily_close = df.groupby("TradeDate")["Close"].last().rename("daily_close")
    daily_ret = daily_close.pct_change().dropna()
    daily_mean = daily_ret.rolling(n_days).mean()
    daily_vol = daily_ret.rolling(n_days).apply(lambda x: np.sqrt(((x - x.mean())**2).mean()))
    vol_df = pd.DataFrame({"Vol": daily_vol, "MeanRet": daily_mean})
    vol_df["Leverage"] = (target_vol / vol_df["Vol"]).clip(upper=4)
    return vol_df

def backtest_strategy(
    df,
    initial_capital=100000.0,
    commission_per_share=0.0035,
    slippage_per_share=0.001,
    target_vol=0.02
):
    df["TimeOfDay"] = df.index.time
    df = df.sort_values(["TradeDate","TimeOfDay"])
    vol_df = compute_daily_volatility(df, n_days=14, target_vol=target_vol)
    df["TradeDate"] = df.index.date
    current_aum = initial_capital
    position = 0
    shares_held = 0
    entry_price = 0.0
    trade_records = []
    last_date = None
    daily_open = df[df.index.strftime("%H:%M")=="09:30"].groupby("TradeDate")["Open"].first()

    def is_semi_hour(t):
        return (t.minute == 0 or t.minute == 30)

    for idx, row in df.iterrows():
        current_date = row["TradeDate"]
        current_time = idx.time()
        current_price = row["Close"]
        upper_bound = row["UpperBound"]
        lower_bound = row["LowerBound"]
        vwap_price = row["vwap"]

        if last_date is None or current_date != last_date:
            open_px = daily_open.get(current_date, np.nan)
            if pd.isnull(open_px):
                open_px = current_price
            leverage = vol_df.loc[current_date, "Leverage"] if current_date in vol_df.index else 1.0
            if pd.isnull(leverage):
                leverage = 1.0
            max_shares_est = (current_aum * leverage) / open_px if open_px>0 else 0
            max_shares = int(np.floor(max_shares_est)) if max_shares_est>0 else 0
            shares_held = 0
            position = 0
            entry_price = 0.0
            last_date = current_date

        if current_time >= datetime.time(16,0):
            if position != 0 and shares_held>0:
                exit_pnl = (current_price - entry_price)*position*shares_held
                fee = (commission_per_share + slippage_per_share)*shares_held
                realized = exit_pnl - fee
                current_aum += realized
                trade_records.append({"date": current_date, "pnl": realized})
            position = 0
            shares_held = 0
            entry_price = 0.0
            continue

        if is_semi_hour(current_time):
            if position != 0 and shares_held>0:
                if position>0:
                    stop_line = max(upper_bound, vwap_price)
                    if current_price <= stop_line:
                        exit_pnl = (current_price - entry_price)*shares_held
                        fee = (commission_per_share + slippage_per_share)*shares_held
                        realized = exit_pnl - fee
                        current_aum += realized
                        trade_records.append({"date": current_date, "pnl": realized})
                        position = 0
                        shares_held = 0
                        entry_price = 0.0
                else:
                    stop_line = min(lower_bound, vwap_price)
                    if current_price >= stop_line:
                        exit_pnl = (entry_price - current_price)*shares_held
                        fee = (commission_per_share + slippage_per_share)*shares_held
                        realized = exit_pnl - fee
                        current_aum += realized
                        trade_records.append({"date": current_date, "pnl": realized})
                        position = 0
                        shares_held = 0
                        entry_price = 0.0

            if position == 0:
                if current_price>upper_bound and max_shares>0:
                    position = 1
                    shares_held = max_shares
                    entry_price = current_price
                elif current_price<lower_bound and max_shares>0:
                    position = -1
                    shares_held = max_shares
                    entry_price = current_price
            else:
                if position>0 and current_price<lower_bound and max_shares>0:
                    exit_pnl = (current_price - entry_price)*shares_held
                    fee = (commission_per_share + slippage_per_share)*shares_held
                    realized = exit_pnl - fee
                    current_aum += realized
                    trade_records.append({"date": current_date, "pnl": realized})
                    position = -1
                    shares_held = max_shares
                    entry_price = current_price
                elif position<0 and current_price>upper_bound and max_shares>0:
                    exit_pnl = (entry_price - current_price)*shares_held
                    fee = (commission_per_share + slippage_per_share)*shares_held
                    realized = exit_pnl - fee
                    current_aum += realized
                    trade_records.append({"date": current_date, "pnl": realized})
                    position = 1
                    shares_held = max_shares
                    entry_price = current_price

    trade_df = pd.DataFrame(trade_records)
    total_pnl = trade_df["pnl"].sum() if not trade_df.empty else 0.0
    trades_count = len(trade_df)
    avg_pnl = total_pnl / trades_count if trades_count else 0.0

    # 按月、年统计
    if not trade_df.empty:
        trade_df["date"] = pd.to_datetime(trade_df["date"])
        trade_df["year"] = trade_df["date"].dt.year
        trade_df["month"] = trade_df["date"].dt.month

        monthly_pnl = trade_df.groupby(["year","month"])["pnl"].sum()
        yearly_pnl = trade_df.groupby(["year"])["pnl"].sum()
    else:
        monthly_pnl = pd.Series(dtype=float)
        yearly_pnl = pd.Series(dtype=float)

    return {
        "FinalAUM": current_aum,
        "TotalPnL": total_pnl,
        "TradesCount": trades_count,
        "AvgPnL": avg_pnl,
        "MonthlyPnL": monthly_pnl,
        "YearlyPnL": yearly_pnl
    }

def main():
    spy_csv = "spy_all.csv"
    vix_csv = "vix_all.csv"
    df_merged = load_data(spy_csv, vix_csv)
    df_merged = compute_14day_abs_moves(df_merged)
    df_merged = rolling_14day_average_move(df_merged)
    df_merged = compute_noise_boundaries(df_merged)
    df_merged = compute_vwap(df_merged)
    result = backtest_strategy(df_merged)
    print("回测结果:")
    print("最终AUM:", result["FinalAUM"])
    print("总盈亏:", result["TotalPnL"])
    print("交易次数:", result["TradesCount"])
    print("平均每笔盈亏:", result["AvgPnL"])
    print("===========")
    print("按月统计:")
    print(result["MonthlyPnL"])
    print("===========")
    print("按年统计:")
    print(result["YearlyPnL"])

if __name__ == "__main__":
    main()
# Out:
# /var/folders/rq/lg6_61n50bb12byh9g0vdc380000gq/T/ipykernel_94480/468042207.py:83: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   cum_pv_series = group_obj.apply(calc_cumpv)
# /var/folders/rq/lg6_61n50bb12byh9g0vdc380000gq/T/ipykernel_94480/468042207.py:84: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   cum_vol_series = group_obj.apply(calc_cumvol)
# 回测结果:
# 最终AUM: 113980.1041000003
# 总盈亏: 13980.104100000535
# 交易次数: 949
# 平均每笔盈亏: 14.731405795574853
# ===========
# 按月统计:
# year  month
# 2008  1       -6166.4313
#       2         232.9750
#       3       -1891.6650
#       4          64.3440
#       5       -1254.8095
#                  ...
# 2024  11        655.6155
#       12        593.0170
# 2025  1        2359.3455
#       2       -5636.3810
#       3        2656.3925
# Name: pnl, Length: 205, dtype: float64
# ===========
# 按年统计:
# year
# 2008   -14767.7933
# 2009    10342.5060
# 2010     6372.0098
# 2011      -46.3863
# 2012     1506.2924
# 2013    -2759.7031
# 2014    -4750.9943
# 2015     6609.3904
# 2016     1489.1960
# 2017     8547.4145
# 2018    -2523.2111
# 2019     3560.1485
# 2020   -10065.3925
# 2021     5045.7379
# 2022     4572.6659
# 2023     3840.6195
# 2024    -2371.7532
# 2025     -620.6430
# Name: pnl, dtype: float64

# %%
import pandas as pd
import numpy as np
from math import floor, sqrt

# -------------------------------
# 辅助函数：计算每日VWAP
# -------------------------------
def compute_vwap(df):
    """计算当日逐分钟累计的VWAP"""
    df = df.copy()
    df['cum_vol'] = df['Volume'].cumsum()
    df['cum_pv'] = (df['Close'] * df['Volume']).cumsum()
    df['VWAP'] = df['cum_pv'] / df['cum_vol']
    return df

# -------------------------------
# 辅助函数：模拟单个交易日内的交易
# -------------------------------
def simulate_day(day_df, allowed_times, position_size):
    """
    模拟单个交易日内的交易（基于Noise Area信号与VWAP动态止损）。
    
    参数：
      day_df: 当日所有分钟数据，需要包含字段 DateTime, Time, Close, UpperBound, LowerBound, VWAP
      allowed_times: 允许触发交易信号的时间点列表，例如 ['09:30', '10:00', ...]
      position_size: 当日固定的交易股数
      
    返回：
      trades: 当日所有交易记录（字典列表），每笔记录包含 entry_time, exit_time, side, entry_price, exit_price, pnl
    """
    position = 0  # 0 表示空仓，1 表示多仓，-1 表示空仓
    entry_price = np.nan
    trailing_stop = np.nan
    trade_entry_time = None
    trades = []
    
    for idx, row in day_df.iterrows():
        current_time = row['Time']
        price = row['Close']
        upper = row['UpperBound']
        lower = row['LowerBound']
        vwap = row['VWAP']
        
        # 在允许的时间点触发开仓信号
        if position == 0 and current_time in allowed_times:
            if price > upper:
                position = 1
                entry_price = price
                trade_entry_time = row['DateTime']
                trailing_stop = max(upper, vwap)  # 多仓初始止损
            elif price < lower:
                position = -1
                entry_price = price
                trade_entry_time = row['DateTime']
                trailing_stop = min(lower, vwap)  # 空仓初始止损
        
        # 如果已有持仓，则更新VWAP和动态止损，并判断是否平仓
        if position != 0:
            if position == 1:
                new_stop = max(upper, vwap)
                trailing_stop = max(trailing_stop, new_stop)
                if price < trailing_stop:
                    exit_time = row['DateTime']
                    pnl = position_size * (price - entry_price)  # 多仓盈亏
                    trades.append({
                        'entry_time': trade_entry_time,
                        'exit_time': exit_time,
                        'side': 'Long',
                        'entry_price': entry_price,
                        'exit_price': price,
                        'pnl': pnl
                    })
                    position = 0
                    trailing_stop = np.nan
            elif position == -1:
                new_stop = min(lower, vwap)
                trailing_stop = min(trailing_stop, new_stop)
                if price > trailing_stop:
                    exit_time = row['DateTime']
                    pnl = position_size * (entry_price - price)  # 空仓盈亏
                    trades.append({
                        'entry_time': trade_entry_time,
                        'exit_time': exit_time,
                        'side': 'Short',
                        'entry_price': entry_price,
                        'exit_price': price,
                        'pnl': pnl
                    })
                    position = 0
                    trailing_stop = np.nan
    # 若日末仍然持仓，则以最后一分钟价格平仓
    if position != 0:
        exit_time = day_df.iloc[-1]['DateTime']
        last_price = day_df.iloc[-1]['Close']
        if position == 1:
            pnl = position_size * (last_price - entry_price)
            trades.append({
                'entry_time': trade_entry_time,
                'exit_time': exit_time,
                'side': 'Long',
                'entry_price': entry_price,
                'exit_price': last_price,
                'pnl': pnl
            })
        else:
            pnl = position_size * (entry_price - last_price)
            trades.append({
                'entry_time': trade_entry_time,
                'exit_time': exit_time,
                'side': 'Short',
                'entry_price': entry_price,
                'exit_price': last_price,
                'pnl': pnl
            })
    return trades

# -------------------------------
# 主程序
# -------------------------------
if __name__ == '__main__':
    # 1. 读取SPY数据 (spy_all.csv)，字段: DateTime, Open, High, Low, Close, Volume
    spy_df = pd.read_csv('spy_all.csv', parse_dates=['DateTime'])
    spy_df.sort_values('DateTime', inplace=True)
    spy_df['Date'] = spy_df['DateTime'].dt.date
    spy_df['Time'] = spy_df['DateTime'].dt.strftime('%H:%M')
    
    # 每日开盘价，取每天第一笔数据
    spy_df['Open_day'] = spy_df.groupby('Date')['Open'].transform('first')
    # 计算每分钟相对于当日开盘价的百分比变化
    spy_df['ret'] = spy_df['Close'] / spy_df['Open_day'] - 1
    
    # 2. 计算过去14天同一时刻的平均绝对涨跌幅（σ）
    pivot = spy_df.pivot(index='Date', columns='Time', values='ret').abs()
    sigma = pivot.rolling(window=14, min_periods=1).mean()
    sigma = sigma.stack().reset_index(name='sigma')
    spy_df = pd.merge(spy_df, sigma, on=['Date', 'Time'], how='left')
    
    # 3. 计算每日收盘价，并获取前一交易日收盘价
    daily_close = spy_df.groupby('Date')['Close'].last().to_frame(name='close').reset_index()
    daily_close['prev_close'] = daily_close['close'].shift(1)
    # 合并到数据中，若首日无prev_close则用当日开盘价替代
    spy_df = pd.merge(spy_df, daily_close[['Date', 'prev_close']], on='Date', how='left')
    spy_df['prev_close'].fillna(spy_df['Open_day'], inplace=True)
    
    # 4. 计算参考值与Noise Area边界
    # 参考上界： max(Open_day, prev_close)，下界： min(Open_day, prev_close)
    spy_df['ref_upper'] = spy_df[['Open_day', 'prev_close']].max(axis=1)
    spy_df['ref_lower'] = spy_df[['Open_day', 'prev_close']].min(axis=1)
    spy_df['UpperBound'] = spy_df['ref_upper'] * (1 + spy_df['sigma'])
    spy_df['LowerBound'] = spy_df['ref_lower'] * (1 - spy_df['sigma'])
    
    # 5. 计算VWAP（基于Volume累加），按日期分组
    spy_df = spy_df.groupby('Date', group_keys=False).apply(compute_vwap)
    
    # 6. 读取VIX数据 (vix_all.csv)，字段: DateTime, Open, High, Low, Close, Volume
    vix_df = pd.read_csv('vix_all.csv', parse_dates=['DateTime'])
    vix_df.sort_values('DateTime', inplace=True)
    vix_df['Date'] = vix_df['DateTime'].dt.date
    vix_df['Time'] = vix_df['DateTime'].dt.strftime('%H:%M')
    vix_min_date = vix_df['Date'].min()
    print("VIX数据最早可用日期：", vix_min_date)
    
    # 7. 动态仓位调整——基于过去14天SPY日收益率标准差
    daily_stats = spy_df.groupby('Date').agg({'Open_day':'first','Close':'last'}).reset_index()
    daily_stats['ret'] = daily_stats['Close'] / daily_stats['Open_day'] - 1
    daily_stats['sigma_spy'] = daily_stats['ret'].rolling(window=14, min_periods=1).std()
    daily_stats.set_index('Date', inplace=True)
    
    # 8. 限制回测范围：仅回测最近5年的数据
    all_dates = sorted(spy_df['Date'].unique())
    last_date = pd.to_datetime(max(all_dates))
    threshold_date = (last_date - pd.DateOffset(years=5)).date()
    # 筛选日期 >= threshold_date 且 >= VIX 最早可用日期
    unique_dates = [d for d in all_dates if d >= threshold_date and d >= vix_min_date]
    
    # 允许交易信号触发的时间点（例如半小时一次）
    allowed_times = ['09:30', '10:00', '10:30', '11:00', '11:30', 
                     '12:00', '12:30', '13:00', '13:30', '14:00', '14:30', '15:00', '15:30']
    
    capital = 100000.0
    daily_results = []  # 用于记录每日资金和收益率
    all_trades = []     # 用于存储所有交易记录
    
    # 开始日内回测：遍历每个交易日，并打印当天的交易记录
    for trade_date in unique_dates:
        day_spy = spy_df[spy_df['Date'] == trade_date].copy().reset_index(drop=True)
        if day_spy.empty:
            continue
        
        # 从VIX数据中获取当天记录，若09:30前无数据则取当天第一条记录
        day_vix = vix_df[vix_df['Date'] == trade_date]
        pre_open_vix = day_vix[day_vix['Time'] < '09:30']
        if pre_open_vix.empty and not day_vix.empty:
            pre_open_vix = day_vix.iloc[[0]]
        if pre_open_vix.empty:
            continue
        vix_value = pre_open_vix.iloc[-1]['Close']
        # 假设VIX为百分比，转换为日化波动率
        daily_vix = (vix_value/100) / sqrt(252)
        
        # 利用SPY数据中每日收益率标准差，如不足则取0.02作为默认值
        sigma_spy = daily_stats.loc[trade_date, 'sigma_spy'] if trade_date in daily_stats.index and daily_stats.loc[trade_date, 'sigma_spy']>0 else 0.02
        target_vol = 0.02
        multiplier = min(4, target_vol / sigma_spy)
        
        open_price = day_spy.iloc[0]['Open_day']
        position_size = floor(capital * multiplier / open_price)
        if position_size <= 0:
            continue
        
        # 模拟当天交易，得到交易记录
        trades = simulate_day(day_spy, allowed_times, position_size)
        # 打印当天的交易记录
        print(f"\n日期: {trade_date}  交易记录:")
        if trades:
            for t in trades:
                print(t)
        else:
            print("  无有效交易记录")
        
        day_pnl = sum(trade['pnl'] for trade in trades)
        capital_start = capital
        capital = capital + day_pnl
        daily_return = (capital - capital_start) / capital_start
        daily_results.append({'Date': trade_date, 'capital': capital, 'daily_return': daily_return})
        for t in trades:
            t['date'] = trade_date
            all_trades.append(t)
    
    # 汇总每日结果，计算每月和每年累计收益率
    daily_df = pd.DataFrame(daily_results)
    daily_df['Date'] = pd.to_datetime(daily_df['Date'])
    daily_df.sort_values('Date', inplace=True)
    daily_df.set_index('Date', inplace=True)
    
    monthly = daily_df.resample('M').agg({'capital': ['first', 'last']})
    monthly.columns = ['month_start', 'month_end']
    monthly['monthly_return'] = monthly['month_end'] / monthly['month_start'] - 1
    
    yearly = daily_df.resample('A').agg({'capital': ['first', 'last']})
    yearly.columns = ['year_start', 'year_end']
    yearly['yearly_return'] = yearly['year_end'] / yearly['year_start'] - 1
    
    print("\n每个月累计收益率:")
    print(monthly[['month_start','month_end','monthly_return']])
    
    print("\n每年累计收益率:")
    print(yearly[['year_start','year_end','yearly_return']])
    
    total_return = capital / 100000.0 - 1
    print(f"\n整个回测期间累计收益率: {total_return*100:.2f}%")
# Out:
# /var/folders/rq/lg6_61n50bb12byh9g0vdc380000gq/T/ipykernel_12012/3691695736.py:143: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   spy_df['prev_close'].fillna(spy_df['Open_day'], inplace=True)
# /var/folders/rq/lg6_61n50bb12byh9g0vdc380000gq/T/ipykernel_12012/3691695736.py:153: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   spy_df = spy_df.groupby('Date', group_keys=False).apply(compute_vwap)
# VIX数据最早可用日期： 2008-01-02
#
# 日期: 2020-04-06  交易记录:
#   无有效交易记录
#
# 日期: 2020-04-07  交易记录:
#   无有效交易记录
#
# 日期: 2020-04-08  交易记录:
# {'entry_time': Timestamp('2020-04-08 11:30:00'), 'exit_time': Timestamp('2020-04-08 12:00:00'), 'side': 'Long', 'entry_price': 270.59, 'exit_price': 270.57, 'pnl': -3.7199999999966167}
# {'entry_time': Timestamp('2020-04-08 14:30:00'), 'exit_time': Timestamp('2020-04-08 15:40:00'), 'side': 'Long', 'entry_price': 272.87, 'exit_price': 272.42, 'pnl': -83.69999999999789}
#
# 日期: 2020-04-09  交易记录:
#   无有效交易记录
#
# 日期: 2020-04-13  交易记录:
#   无有效交易记录
#
# 日期: 2020-04-14  交易记录:
# {'entry_time': Timestamp('2020-04-14 10:30:00'), 'exit_time': Timestamp('2020-04-14 10:32:00'), 'side': 'Long', 'entry_price': 282.78, 'exit_price': 282.57, 'pnl': -47.039999999995416}
#
# 日期: 2020-04-15  交易记录:
# {'entry_time': Timestamp('2020-04-15 10:30:00'), 'exit_time': Timestamp('2020-04-15 10:45:00'), 'side': 'Short', 'entry_price': 276.12, 'exit_price': 276.615, 'pnl': -107.91000000000099}
# {'entry_time': Timestamp('2020-04-15 11:00:00'), 'exit_time': Timestamp('2020-04-15 11:30:00'), 'side': 'Short', 'entry_price': 276.5401, 'exit_price': 276.94, 'pnl': -87.17820000000052}
#
# 日期: 2020-04-16  交易记录:
#   无有效交易记录
#
# 日期: 2020-04-17  交易记录:
# {'entry_time': Timestamp('2020-04-17 10:30:00'), 'exit_time': Timestamp('2020-04-17 10:40:00'), 'side': 'Short', 'entry_price': 283.76, 'exit_price': 283.61, 'pnl': 44.54999999999325}
# {'entry_time': Timestamp('2020-04-17 11:00:00'), 'exit_time': Timestamp('2020-04-17 11:01:00'), 'side': 'Short', 'entry_price': 283.565, 'exit_price': 283.768, 'pnl': -60.29099999999244}
# {'entry_time': Timestamp('2020-04-17 11:30:00'), 'exit_time': Timestamp('2020-04-17 11:37:00'), 'side': 'Short', 'entry_price': 282.93, 'exit_price': 283.6, 'pnl': -198.99000000000473}
#
# 日期: 2020-04-20  交易记录:
# {'entry_time': Timestamp('2020-04-20 09:30:00'), 'exit_time': Timestamp('2020-04-20 09:30:00'), 'side': 'Short', 'entry_price': 282.3703, 'exit_price': 282.3703, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-04-20 10:00:00'), 'exit_time': Timestamp('2020-04-20 10:00:00'), 'side': 'Short', 'entry_price': 283.15, 'exit_price': 283.15, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-04-20 10:30:00'), 'exit_time': Timestamp('2020-04-20 10:30:00'), 'side': 'Short', 'entry_price': 283.85, 'exit_price': 283.85, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-04-20 15:00:00'), 'exit_time': Timestamp('2020-04-20 15:29:00'), 'side': 'Short', 'entry_price': 282.1067, 'exit_price': 282.44, 'pnl': -111.6555000000028}
#
# 日期: 2020-04-21  交易记录:
# {'entry_time': Timestamp('2020-04-21 09:30:00'), 'exit_time': Timestamp('2020-04-21 09:30:00'), 'side': 'Short', 'entry_price': 276.79, 'exit_price': 276.79, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-04-21 10:30:00'), 'exit_time': Timestamp('2020-04-21 10:30:00'), 'side': 'Short', 'entry_price': 276.77, 'exit_price': 276.77, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-04-21 11:00:00'), 'exit_time': Timestamp('2020-04-21 13:37:00'), 'side': 'Short', 'entry_price': 273.97, 'exit_price': 274.87, 'pnl': -332.9999999999916}
# {'entry_time': Timestamp('2020-04-21 14:00:00'), 'exit_time': Timestamp('2020-04-21 14:07:00'), 'side': 'Short', 'entry_price': 273.69, 'exit_price': 274.78, 'pnl': -403.29999999999075}
# {'entry_time': Timestamp('2020-04-21 14:30:00'), 'exit_time': Timestamp('2020-04-21 14:30:00'), 'side': 'Short', 'entry_price': 274.84, 'exit_price': 274.84, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-04-21 15:00:00'), 'exit_time': Timestamp('2020-04-21 15:20:00'), 'side': 'Short', 'entry_price': 273.83, 'exit_price': 274.68, 'pnl': -314.5000000000084}
# {'entry_time': Timestamp('2020-04-21 15:30:00'), 'exit_time': Timestamp('2020-04-21 15:35:00'), 'side': 'Short', 'entry_price': 274.38, 'exit_price': 275.15, 'pnl': -284.89999999999327}
#
# 日期: 2020-04-22  交易记录:
# {'entry_time': Timestamp('2020-04-22 09:30:00'), 'exit_time': Timestamp('2020-04-22 09:32:00'), 'side': 'Long', 'entry_price': 278.48, 'exit_price': 277.63, 'pnl': -328.1000000000088}
# {'entry_time': Timestamp('2020-04-22 10:30:00'), 'exit_time': Timestamp('2020-04-22 10:46:00'), 'side': 'Long', 'entry_price': 277.82, 'exit_price': 278.19, 'pnl': 142.82000000000176}
# {'entry_time': Timestamp('2020-04-22 11:30:00'), 'exit_time': Timestamp('2020-04-22 12:08:00'), 'side': 'Long', 'entry_price': 278.25, 'exit_price': 278.42, 'pnl': 65.62000000000614}
# {'entry_time': Timestamp('2020-04-22 12:30:00'), 'exit_time': Timestamp('2020-04-22 12:34:00'), 'side': 'Long', 'entry_price': 278.96, 'exit_price': 278.79, 'pnl': -65.6199999999842}
# {'entry_time': Timestamp('2020-04-22 13:30:00'), 'exit_time': Timestamp('2020-04-22 15:58:00'), 'side': 'Long', 'entry_price': 279.2101, 'exit_price': 279.38, 'pnl': 65.58139999999389}
#
# 日期: 2020-04-23  交易记录:
# {'entry_time': Timestamp('2020-04-23 09:30:00'), 'exit_time': Timestamp('2020-04-23 09:58:00'), 'side': 'Long', 'entry_price': 280.41, 'exit_price': 281.137, 'pnl': 276.25999999999067}
# {'entry_time': Timestamp('2020-04-23 10:00:00'), 'exit_time': Timestamp('2020-04-23 11:45:00'), 'side': 'Long', 'entry_price': 281.71, 'exit_price': 281.9603, 'pnl': 95.11400000001458}
# {'entry_time': Timestamp('2020-04-23 12:00:00'), 'exit_time': Timestamp('2020-04-23 12:44:00'), 'side': 'Long', 'entry_price': 282.26, 'exit_price': 281.19, 'pnl': -406.5999999999974}
#
# 日期: 2020-04-24  交易记录:
# {'entry_time': Timestamp('2020-04-24 09:30:00'), 'exit_time': Timestamp('2020-04-24 09:35:00'), 'side': 'Long', 'entry_price': 281.01, 'exit_price': 280.4, 'pnl': -231.80000000000518}
# {'entry_time': Timestamp('2020-04-24 14:00:00'), 'exit_time': Timestamp('2020-04-24 17:16:00'), 'side': 'Long', 'entry_price': 281.39, 'exit_price': 282.82, 'pnl': 543.4000000000026}
#
# 日期: 2020-04-27  交易记录:
#   无有效交易记录
#
# 日期: 2020-04-28  交易记录:
# {'entry_time': Timestamp('2020-04-28 09:30:00'), 'exit_time': Timestamp('2020-04-28 09:32:00'), 'side': 'Long', 'entry_price': 291.24, 'exit_price': 290.84, 'pnl': -175.60000000001497}
#
# 日期: 2020-04-29  交易记录:
# {'entry_time': Timestamp('2020-04-29 10:00:00'), 'exit_time': Timestamp('2020-04-29 10:02:00'), 'side': 'Long', 'entry_price': 291.73, 'exit_price': 291.59, 'pnl': -69.44000000002143}
# {'entry_time': Timestamp('2020-04-29 10:30:00'), 'exit_time': Timestamp('2020-04-29 10:37:00'), 'side': 'Long', 'entry_price': 292.28, 'exit_price': 291.8702, 'pnl': -203.26079999998092}
# {'entry_time': Timestamp('2020-04-29 11:00:00'), 'exit_time': Timestamp('2020-04-29 19:59:00'), 'side': 'Long', 'entry_price': 292.5157, 'exit_price': np.float64(294.8), 'pnl': np.float64(1133.012800000015)}
#
# 日期: 2020-04-30  交易记录:
# {'entry_time': Timestamp('2020-04-30 09:30:00'), 'exit_time': Timestamp('2020-04-30 09:56:00'), 'side': 'Short', 'entry_price': 291.28, 'exit_price': 291.21, 'pnl': 30.659999999997012}
# {'entry_time': Timestamp('2020-04-30 10:00:00'), 'exit_time': Timestamp('2020-04-30 10:00:00'), 'side': 'Short', 'entry_price': 291.88, 'exit_price': 291.88, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-04-30 11:00:00'), 'exit_time': Timestamp('2020-04-30 11:00:00'), 'side': 'Short', 'entry_price': 291.49, 'exit_price': 291.49, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-04-30 11:30:00'), 'exit_time': Timestamp('2020-04-30 11:40:00'), 'side': 'Short', 'entry_price': 290.86, 'exit_price': 291.26, 'pnl': -175.19999999999004}
# {'entry_time': Timestamp('2020-04-30 12:00:00'), 'exit_time': Timestamp('2020-04-30 15:17:00'), 'side': 'Short', 'entry_price': 289.4301, 'exit_price': 290.4499, 'pnl': -446.672400000014}
# {'entry_time': Timestamp('2020-04-30 15:30:00'), 'exit_time': Timestamp('2020-04-30 15:30:00'), 'side': 'Short', 'entry_price': 290.62, 'exit_price': 290.62, 'pnl': 0.0}
#
# 日期: 2020-05-01  交易记录:
#   无有效交易记录
#
# 日期: 2020-05-04  交易记录:
#   无有效交易记录
#
# 日期: 2020-05-05  交易记录:
# {'entry_time': Timestamp('2020-05-05 10:00:00'), 'exit_time': Timestamp('2020-05-05 10:05:00'), 'side': 'Long', 'entry_price': 288.28, 'exit_price': 288.0598, 'pnl': -106.5767999999889}
# {'entry_time': Timestamp('2020-05-05 11:30:00'), 'exit_time': Timestamp('2020-05-05 12:24:00'), 'side': 'Long', 'entry_price': 288.66, 'exit_price': 289.0, 'pnl': 164.5599999999879}
# {'entry_time': Timestamp('2020-05-05 14:30:00'), 'exit_time': Timestamp('2020-05-05 14:33:00'), 'side': 'Long', 'entry_price': 288.965, 'exit_price': 288.76, 'pnl': -99.2199999999923}
#
# 日期: 2020-05-06  交易记录:
#   无有效交易记录
#
# 日期: 2020-05-07  交易记录:
# {'entry_time': Timestamp('2020-05-07 10:00:00'), 'exit_time': Timestamp('2020-05-07 10:02:00'), 'side': 'Long', 'entry_price': 288.62, 'exit_price': 288.35, 'pnl': -141.47999999999047}
# {'entry_time': Timestamp('2020-05-07 12:00:00'), 'exit_time': Timestamp('2020-05-07 12:04:00'), 'side': 'Long', 'entry_price': 289.69, 'exit_price': 289.24, 'pnl': -235.79999999999404}
# {'entry_time': Timestamp('2020-05-07 13:00:00'), 'exit_time': Timestamp('2020-05-07 13:19:00'), 'side': 'Long', 'entry_price': 289.235, 'exit_price': 289.17, 'pnl': -34.05999999999881}
#
# 日期: 2020-05-08  交易记录:
#   无有效交易记录
#
# 日期: 2020-05-11  交易记录:
# {'entry_time': Timestamp('2020-05-11 09:30:00'), 'exit_time': Timestamp('2020-05-11 09:36:00'), 'side': 'Short', 'entry_price': 290.13, 'exit_price': 290.45, 'pnl': -179.83999999999617}
# {'entry_time': Timestamp('2020-05-11 10:00:00'), 'exit_time': Timestamp('2020-05-11 10:00:00'), 'side': 'Short', 'entry_price': 290.63, 'exit_price': 290.63, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-05-11 10:30:00'), 'exit_time': Timestamp('2020-05-11 10:31:00'), 'side': 'Short', 'entry_price': 290.65, 'exit_price': 290.9, 'pnl': -140.5}
# {'entry_time': Timestamp('2020-05-11 11:00:00'), 'exit_time': Timestamp('2020-05-11 11:00:00'), 'side': 'Short', 'entry_price': 290.94, 'exit_price': 290.94, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-05-11 11:30:00'), 'exit_time': Timestamp('2020-05-11 11:30:00'), 'side': 'Short', 'entry_price': 291.78, 'exit_price': 291.78, 'pnl': 0.0}
#
# 日期: 2020-05-12  交易记录:
# {'entry_time': Timestamp('2020-05-12 09:30:00'), 'exit_time': Timestamp('2020-05-12 09:33:00'), 'side': 'Long', 'entry_price': 293.99, 'exit_price': 293.69, 'pnl': -140.1000000000053}
# {'entry_time': Timestamp('2020-05-12 15:30:00'), 'exit_time': Timestamp('2020-05-12 15:31:00'), 'side': 'Short', 'entry_price': 289.7, 'exit_price': 289.6263, 'pnl': 34.41789999998781}
#
# 日期: 2020-05-13  交易记录:
# {'entry_time': Timestamp('2020-05-13 14:00:00'), 'exit_time': Timestamp('2020-05-13 14:11:00'), 'side': 'Short', 'entry_price': 280.7, 'exit_price': 281.23, 'pnl': -246.45000000001374}
# {'entry_time': Timestamp('2020-05-13 14:30:00'), 'exit_time': Timestamp('2020-05-13 15:02:00'), 'side': 'Short', 'entry_price': 280.78, 'exit_price': 281.23, 'pnl': -209.25000000002115}
# {'entry_time': Timestamp('2020-05-13 15:30:00'), 'exit_time': Timestamp('2020-05-13 15:42:00'), 'side': 'Short', 'entry_price': 279.79, 'exit_price': 280.79, 'pnl': -465.0}
#
# 日期: 2020-05-14  交易记录:
# {'entry_time': Timestamp('2020-05-14 09:30:00'), 'exit_time': Timestamp('2020-05-14 09:31:00'), 'side': 'Short', 'entry_price': 279.16, 'exit_price': 279.65, 'pnl': -233.72999999997722}
# {'entry_time': Timestamp('2020-05-14 10:00:00'), 'exit_time': Timestamp('2020-05-14 10:25:00'), 'side': 'Short', 'entry_price': 276.81, 'exit_price': 278.2, 'pnl': -663.0299999999935}
# {'entry_time': Timestamp('2020-05-14 10:30:00'), 'exit_time': Timestamp('2020-05-14 10:34:00'), 'side': 'Short', 'entry_price': 277.4033, 'exit_price': 278.12, 'pnl': -341.86590000000143}
# {'entry_time': Timestamp('2020-05-14 11:00:00'), 'exit_time': Timestamp('2020-05-14 11:00:00'), 'side': 'Short', 'entry_price': 280.02, 'exit_price': 280.02, 'pnl': 0.0}
#
# 日期: 2020-05-15  交易记录:
# {'entry_time': Timestamp('2020-05-15 09:30:00'), 'exit_time': Timestamp('2020-05-15 09:30:00'), 'side': 'Short', 'entry_price': 282.45, 'exit_price': 282.45, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-05-15 10:00:00'), 'exit_time': Timestamp('2020-05-15 10:00:00'), 'side': 'Short', 'entry_price': 283.85, 'exit_price': 283.85, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-05-15 10:30:00'), 'exit_time': Timestamp('2020-05-15 10:30:00'), 'side': 'Short', 'entry_price': 284.04, 'exit_price': 284.04, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-05-15 11:00:00'), 'exit_time': Timestamp('2020-05-15 12:00:00'), 'side': 'Short', 'entry_price': 282.33, 'exit_price': 283.36, 'pnl': -481.0100000000138}
#
# 日期: 2020-05-18  交易记录:
# {'entry_time': Timestamp('2020-05-18 09:30:00'), 'exit_time': Timestamp('2020-05-18 09:53:00'), 'side': 'Long', 'entry_price': 293.2302, 'exit_price': 292.94, 'pnl': -121.59380000001136}
# {'entry_time': Timestamp('2020-05-18 10:00:00'), 'exit_time': Timestamp('2020-05-18 10:03:00'), 'side': 'Long', 'entry_price': 293.32, 'exit_price': 293.1423, 'pnl': -74.45630000000659}
# {'entry_time': Timestamp('2020-05-18 10:30:00'), 'exit_time': Timestamp('2020-05-18 16:01:00'), 'side': 'Long', 'entry_price': 293.49, 'exit_price': 294.66, 'pnl': 490.23000000000667}
#
# 日期: 2020-05-19  交易记录:
#   无有效交易记录
#
# 日期: 2020-05-20  交易记录:
# {'entry_time': Timestamp('2020-05-20 09:30:00'), 'exit_time': Timestamp('2020-05-20 12:17:00'), 'side': 'Long', 'entry_price': 296.07, 'exit_price': 296.83, 'pnl': 351.8799999999958}
# {'entry_time': Timestamp('2020-05-20 12:30:00'), 'exit_time': Timestamp('2020-05-20 12:30:00'), 'side': 'Long', 'entry_price': 296.85, 'exit_price': 296.85, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-05-20 13:00:00'), 'exit_time': Timestamp('2020-05-20 13:04:00'), 'side': 'Long', 'entry_price': 296.9101, 'exit_price': 296.81, 'pnl': -46.346299999998905}
# {'entry_time': Timestamp('2020-05-20 13:30:00'), 'exit_time': Timestamp('2020-05-20 13:30:00'), 'side': 'Long', 'entry_price': 296.37, 'exit_price': 296.37, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-05-20 14:00:00'), 'exit_time': Timestamp('2020-05-20 14:00:00'), 'side': 'Long', 'entry_price': 296.63, 'exit_price': 296.63, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-05-20 14:30:00'), 'exit_time': Timestamp('2020-05-20 14:30:00'), 'side': 'Long', 'entry_price': 296.445, 'exit_price': 296.445, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-05-20 15:00:00'), 'exit_time': Timestamp('2020-05-20 15:11:00'), 'side': 'Long', 'entry_price': 297.16, 'exit_price': 296.443, 'pnl': -331.97100000001916}
# {'entry_time': Timestamp('2020-05-20 15:30:00'), 'exit_time': Timestamp('2020-05-20 15:48:00'), 'side': 'Long', 'entry_price': 297.05, 'exit_price': 296.6621, 'pnl': -179.59770000000088}
#
# 日期: 2020-05-21  交易记录:
#   无有效交易记录
#
# 日期: 2020-05-22  交易记录:
#   无有效交易记录
#
# 日期: 2020-05-26  交易记录:
#   无有效交易记录
#
# 日期: 2020-05-27  交易记录:
#   无有效交易记录
#
# 日期: 2020-05-28  交易记录:
#   无有效交易记录
#
# 日期: 2020-05-29  交易记录:
#   无有效交易记录
#
# 日期: 2020-06-01  交易记录:
# {'entry_time': Timestamp('2020-06-01 09:30:00'), 'exit_time': Timestamp('2020-06-01 09:31:00'), 'side': 'Short', 'entry_price': 303.12, 'exit_price': 303.84, 'pnl': -326.1599999999866}
#
# 日期: 2020-06-02  交易记录:
#   无有效交易记录
#
# 日期: 2020-06-03  交易记录:
# {'entry_time': Timestamp('2020-06-03 11:30:00'), 'exit_time': Timestamp('2020-06-03 12:17:00'), 'side': 'Long', 'entry_price': 311.68, 'exit_price': 311.3023, 'pnl': -238.32870000000275}
# {'entry_time': Timestamp('2020-06-03 12:30:00'), 'exit_time': Timestamp('2020-06-03 13:51:00'), 'side': 'Long', 'entry_price': 311.58, 'exit_price': 311.25, 'pnl': -208.22999999998996}
# {'entry_time': Timestamp('2020-06-03 14:00:00'), 'exit_time': Timestamp('2020-06-03 16:03:00'), 'side': 'Long', 'entry_price': 311.58, 'exit_price': 311.9, 'pnl': 201.9199999999957}
#
# 日期: 2020-06-04  交易记录:
#   无有效交易记录
#
# 日期: 2020-06-05  交易记录:
# {'entry_time': Timestamp('2020-06-05 09:30:00'), 'exit_time': Timestamp('2020-06-05 15:13:00'), 'side': 'Long', 'entry_price': 317.56, 'exit_price': 319.17, 'pnl': 1012.6900000000086}
# {'entry_time': Timestamp('2020-06-05 15:30:00'), 'exit_time': Timestamp('2020-06-05 15:43:00'), 'side': 'Long', 'entry_price': 319.935, 'exit_price': 319.05, 'pnl': -556.6649999999943}
#
# 日期: 2020-06-08  交易记录:
# {'entry_time': Timestamp('2020-06-08 11:30:00'), 'exit_time': Timestamp('2020-06-08 11:36:00'), 'side': 'Long', 'entry_price': 321.14, 'exit_price': 320.85, 'pnl': -202.4199999999746}
# {'entry_time': Timestamp('2020-06-08 12:00:00'), 'exit_time': Timestamp('2020-06-08 12:14:00'), 'side': 'Long', 'entry_price': 320.9, 'exit_price': 320.5, 'pnl': -279.19999999998413}
# {'entry_time': Timestamp('2020-06-08 13:30:00'), 'exit_time': Timestamp('2020-06-08 13:32:00'), 'side': 'Long', 'entry_price': 321.08, 'exit_price': 320.953, 'pnl': -88.64600000000667}
# {'entry_time': Timestamp('2020-06-08 14:00:00'), 'exit_time': Timestamp('2020-06-08 19:59:00'), 'side': 'Long', 'entry_price': 321.64, 'exit_price': np.float64(322.61), 'pnl': np.float64(677.060000000019)}
#
# 日期: 2020-06-09  交易记录:
# {'entry_time': Timestamp('2020-06-09 10:00:00'), 'exit_time': Timestamp('2020-06-09 10:03:00'), 'side': 'Short', 'entry_price': 319.46, 'exit_price': 319.71, 'pnl': -196.75}
#
# 日期: 2020-06-10  交易记录:
# {'entry_time': Timestamp('2020-06-10 10:30:00'), 'exit_time': Timestamp('2020-06-10 11:40:00'), 'side': 'Short', 'entry_price': 319.01, 'exit_price': 320.11, 'pnl': -675.400000000014}
# {'entry_time': Timestamp('2020-06-10 12:00:00'), 'exit_time': Timestamp('2020-06-10 12:00:00'), 'side': 'Short', 'entry_price': 319.91, 'exit_price': 319.91, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-06-10 12:30:00'), 'exit_time': Timestamp('2020-06-10 12:30:00'), 'side': 'Short', 'entry_price': 320.29, 'exit_price': 320.29, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-06-10 13:00:00'), 'exit_time': Timestamp('2020-06-10 13:02:00'), 'side': 'Short', 'entry_price': 319.825, 'exit_price': 319.94, 'pnl': -70.61000000000558}
# {'entry_time': Timestamp('2020-06-10 14:00:00'), 'exit_time': Timestamp('2020-06-10 14:01:00'), 'side': 'Short', 'entry_price': 319.36, 'exit_price': 320.49, 'pnl': -693.8199999999972}
# {'entry_time': Timestamp('2020-06-10 15:00:00'), 'exit_time': Timestamp('2020-06-10 15:08:00'), 'side': 'Short', 'entry_price': 319.76, 'exit_price': 320.32, 'pnl': -343.8400000000014}
#
# 日期: 2020-06-11  交易记录:
# {'entry_time': Timestamp('2020-06-11 09:30:00'), 'exit_time': Timestamp('2020-06-11 09:46:00'), 'side': 'Short', 'entry_price': 311.02, 'exit_price': 311.24, 'pnl': -94.82000000001176}
# {'entry_time': Timestamp('2020-06-11 10:00:00'), 'exit_time': Timestamp('2020-06-11 10:00:00'), 'side': 'Short', 'entry_price': 311.93, 'exit_price': 311.93, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-06-11 10:30:00'), 'exit_time': Timestamp('2020-06-11 19:59:00'), 'side': 'Short', 'entry_price': 310.44, 'exit_price': np.float64(303.08), 'pnl': np.float64(3172.1600000000058)}
#
# 日期: 2020-06-12  交易记录:
# {'entry_time': Timestamp('2020-06-12 09:30:00'), 'exit_time': Timestamp('2020-06-12 09:49:00'), 'side': 'Long', 'entry_price': 308.17, 'exit_price': 307.58, 'pnl': -279.6600000000151}
# {'entry_time': Timestamp('2020-06-12 10:00:00'), 'exit_time': Timestamp('2020-06-12 10:00:00'), 'side': 'Long', 'entry_price': 307.54, 'exit_price': 307.54, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-06-12 10:30:00'), 'exit_time': Timestamp('2020-06-12 10:30:00'), 'side': 'Long', 'entry_price': 306.286, 'exit_price': 306.286, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-06-12 14:00:00'), 'exit_time': Timestamp('2020-06-12 14:12:00'), 'side': 'Short', 'entry_price': 299.38, 'exit_price': 300.8499, 'pnl': -696.7325999999979}
#
# 日期: 2020-06-15  交易记录:
# {'entry_time': Timestamp('2020-06-15 14:30:00'), 'exit_time': Timestamp('2020-06-15 14:52:00'), 'side': 'Long', 'entry_price': 307.67, 'exit_price': 306.76, 'pnl': -323.0500000000089}
# {'entry_time': Timestamp('2020-06-15 15:00:00'), 'exit_time': Timestamp('2020-06-15 15:21:00'), 'side': 'Long', 'entry_price': 306.98, 'exit_price': 306.29, 'pnl': -244.9499999999992}
#
# 日期: 2020-06-16  交易记录:
# {'entry_time': Timestamp('2020-06-16 09:30:00'), 'exit_time': Timestamp('2020-06-16 09:34:00'), 'side': 'Long', 'entry_price': 315.29, 'exit_price': 314.4, 'pnl': -298.1500000000145}
# {'entry_time': Timestamp('2020-06-16 10:00:00'), 'exit_time': Timestamp('2020-06-16 10:37:00'), 'side': 'Long', 'entry_price': 314.77, 'exit_price': 313.71, 'pnl': -355.10000000000076}
# {'entry_time': Timestamp('2020-06-16 12:00:00'), 'exit_time': Timestamp('2020-06-16 12:00:00'), 'side': 'Long', 'entry_price': 312.44, 'exit_price': 312.44, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-06-16 12:30:00'), 'exit_time': Timestamp('2020-06-16 13:34:00'), 'side': 'Long', 'entry_price': 313.12, 'exit_price': 313.17, 'pnl': 16.75000000000381}
# {'entry_time': Timestamp('2020-06-16 14:30:00'), 'exit_time': Timestamp('2020-06-16 14:40:00'), 'side': 'Long', 'entry_price': 313.86, 'exit_price': 313.32, 'pnl': -180.90000000000686}
#
# 日期: 2020-06-17  交易记录:
# {'entry_time': Timestamp('2020-06-17 10:30:00'), 'exit_time': Timestamp('2020-06-17 10:31:00'), 'side': 'Short', 'entry_price': 311.35, 'exit_price': 311.98, 'pnl': -201.59999999999854}
#
# 日期: 2020-06-18  交易记录:
#   无有效交易记录
#
# 日期: 2020-06-19  交易记录:
# {'entry_time': Timestamp('2020-06-19 12:30:00'), 'exit_time': Timestamp('2020-06-19 12:33:00'), 'side': 'Short', 'entry_price': 309.49, 'exit_price': 309.59, 'pnl': -30.999999999989427}
# {'entry_time': Timestamp('2020-06-19 13:30:00'), 'exit_time': Timestamp('2020-06-19 13:37:00'), 'side': 'Short', 'entry_price': 308.65, 'exit_price': 309.08, 'pnl': -133.30000000000211}
# {'entry_time': Timestamp('2020-06-19 14:00:00'), 'exit_time': Timestamp('2020-06-19 14:36:00'), 'side': 'Short', 'entry_price': 308.3895, 'exit_price': 308.62, 'pnl': -71.45500000000197}
#
# 日期: 2020-06-22  交易记录:
#   无有效交易记录
#
# 日期: 2020-06-23  交易记录:
#   无有效交易记录
#
# 日期: 2020-06-24  交易记录:
# {'entry_time': Timestamp('2020-06-24 10:00:00'), 'exit_time': Timestamp('2020-06-24 15:18:00'), 'side': 'Short', 'entry_price': 307.7101, 'exit_price': 305.44, 'pnl': 671.949600000004}
# {'entry_time': Timestamp('2020-06-24 15:30:00'), 'exit_time': Timestamp('2020-06-24 15:44:00'), 'side': 'Short', 'entry_price': 304.8, 'exit_price': 305.4233, 'pnl': -184.4967999999917}
#
# 日期: 2020-06-25  交易记录:
#   无有效交易记录
#
# 日期: 2020-06-26  交易记录:
# {'entry_time': Timestamp('2020-06-26 10:30:00'), 'exit_time': Timestamp('2020-06-26 19:59:00'), 'side': 'Short', 'entry_price': 303.03, 'exit_price': np.float64(300.15), 'pnl': np.float64(838.0799999999987)}
#
# 日期: 2020-06-29  交易记录:
#   无有效交易记录
#
# 日期: 2020-06-30  交易记录:
#   无有效交易记录
#
# 日期: 2020-07-01  交易记录:
# {'entry_time': Timestamp('2020-07-01 10:30:00'), 'exit_time': Timestamp('2020-07-01 10:34:00'), 'side': 'Long', 'entry_price': 311.1, 'exit_price': 310.9138, 'pnl': -59.77020000001352}
#
# 日期: 2020-07-02  交易记录:
# {'entry_time': Timestamp('2020-07-02 09:30:00'), 'exit_time': Timestamp('2020-07-02 10:13:00'), 'side': 'Long', 'entry_price': 314.321, 'exit_price': 314.66, 'pnl': 108.14099999999956}
#
# 日期: 2020-07-06  交易记录:
#   无有效交易记录
#
# 日期: 2020-07-07  交易记录:
#   无有效交易记录
#
# 日期: 2020-07-08  交易记录:
# {'entry_time': Timestamp('2020-07-08 10:00:00'), 'exit_time': Timestamp('2020-07-08 10:04:00'), 'side': 'Long', 'entry_price': 315.86, 'exit_price': 315.95, 'pnl': 39.779999999988945}
#
# 日期: 2020-07-09  交易记录:
# {'entry_time': Timestamp('2020-07-09 11:00:00'), 'exit_time': Timestamp('2020-07-09 12:47:00'), 'side': 'Short', 'entry_price': 312.115, 'exit_price': 313.58, 'pnl': -644.599999999989}
# {'entry_time': Timestamp('2020-07-09 13:00:00'), 'exit_time': Timestamp('2020-07-09 13:01:00'), 'side': 'Short', 'entry_price': 313.36, 'exit_price': 313.83, 'pnl': -206.799999999987}
# {'entry_time': Timestamp('2020-07-09 14:00:00'), 'exit_time': Timestamp('2020-07-09 14:01:00'), 'side': 'Short', 'entry_price': 313.475, 'exit_price': 313.5031, 'pnl': -12.363999999997759}
#
# 日期: 2020-07-10  交易记录:
#   无有效交易记录
#
# 日期: 2020-07-13  交易记录:
# {'entry_time': Timestamp('2020-07-13 09:30:00'), 'exit_time': Timestamp('2020-07-13 09:31:00'), 'side': 'Long', 'entry_price': 320.32, 'exit_price': 320.04, 'pnl': -124.31999999998789}
# {'entry_time': Timestamp('2020-07-13 10:30:00'), 'exit_time': Timestamp('2020-07-13 10:36:00'), 'side': 'Long', 'entry_price': 321.0525, 'exit_price': 320.76, 'pnl': -129.87000000000808}
# {'entry_time': Timestamp('2020-07-13 11:00:00'), 'exit_time': Timestamp('2020-07-13 11:47:00'), 'side': 'Long', 'entry_price': 321.54, 'exit_price': 321.59, 'pnl': 22.19999999997981}
# {'entry_time': Timestamp('2020-07-13 12:00:00'), 'exit_time': Timestamp('2020-07-13 12:54:00'), 'side': 'Long', 'entry_price': 321.77, 'exit_price': 321.58, 'pnl': -84.35999999999899}
# {'entry_time': Timestamp('2020-07-13 13:00:00'), 'exit_time': Timestamp('2020-07-13 14:03:00'), 'side': 'Long', 'entry_price': 321.78, 'exit_price': 321.61, 'pnl': -75.47999999998183}
#
# 日期: 2020-07-14  交易记录:
# {'entry_time': Timestamp('2020-07-14 09:30:00'), 'exit_time': Timestamp('2020-07-14 09:32:00'), 'side': 'Short', 'entry_price': 313.28, 'exit_price': 314.1557, 'pnl': -373.92390000002206}
#
# 日期: 2020-07-15  交易记录:
# {'entry_time': Timestamp('2020-07-15 09:30:00'), 'exit_time': Timestamp('2020-07-15 09:30:00'), 'side': 'Long', 'entry_price': 322.48, 'exit_price': 322.48, 'pnl': 0.0}
#
# 日期: 2020-07-16  交易记录:
#   无有效交易记录
#
# 日期: 2020-07-17  交易记录:
# {'entry_time': Timestamp('2020-07-17 09:30:00'), 'exit_time': Timestamp('2020-07-17 09:33:00'), 'side': 'Long', 'entry_price': 321.58, 'exit_price': 321.38, 'pnl': -134.79999999999234}
# {'entry_time': Timestamp('2020-07-17 15:00:00'), 'exit_time': Timestamp('2020-07-17 15:01:00'), 'side': 'Long', 'entry_price': 322.065, 'exit_price': 321.69, 'pnl': -252.75}
#
# 日期: 2020-07-20  交易记录:
# {'entry_time': Timestamp('2020-07-20 15:00:00'), 'exit_time': Timestamp('2020-07-20 15:11:00'), 'side': 'Long', 'entry_price': 323.85, 'exit_price': 323.66, 'pnl': -127.48999999999847}
# {'entry_time': Timestamp('2020-07-20 15:30:00'), 'exit_time': Timestamp('2020-07-20 15:59:00'), 'side': 'Long', 'entry_price': 324.5899, 'exit_price': 324.36, 'pnl': -154.2628999999909}
#
# 日期: 2020-07-21  交易记录:
#   无有效交易记录
#
# 日期: 2020-07-22  交易记录:
#   无有效交易记录
#
# 日期: 2020-07-23  交易记录:
# {'entry_time': Timestamp('2020-07-23 14:00:00'), 'exit_time': Timestamp('2020-07-23 17:17:00'), 'side': 'Short', 'entry_price': 323.34, 'exit_price': 322.98, 'pnl': 206.99999999997516}
#
# 日期: 2020-07-24  交易记录:
#   无有效交易记录
#
# 日期: 2020-07-27  交易记录:
# {'entry_time': Timestamp('2020-07-27 10:00:00'), 'exit_time': Timestamp('2020-07-27 10:05:00'), 'side': 'Long', 'entry_price': 322.655, 'exit_price': 322.5, 'pnl': -92.22499999998377}
#
# 日期: 2020-07-28  交易记录:
# {'entry_time': Timestamp('2020-07-28 10:00:00'), 'exit_time': Timestamp('2020-07-28 10:04:00'), 'side': 'Short', 'entry_price': 322.01, 'exit_price': 322.3, 'pnl': -167.91000000001185}
#
# 日期: 2020-07-29  交易记录:
# {'entry_time': Timestamp('2020-07-29 10:30:00'), 'exit_time': Timestamp('2020-07-29 12:09:00'), 'side': 'Long', 'entry_price': 323.23, 'exit_price': 323.24, 'pnl': 5.789999999994734}
# {'entry_time': Timestamp('2020-07-29 12:30:00'), 'exit_time': Timestamp('2020-07-29 15:54:00'), 'side': 'Long', 'entry_price': 323.71, 'exit_price': 324.7, 'pnl': 573.2100000000053}
#
# 日期: 2020-07-30  交易记录:
# {'entry_time': Timestamp('2020-07-30 09:30:00'), 'exit_time': Timestamp('2020-07-30 09:33:00'), 'side': 'Short', 'entry_price': 321.62, 'exit_price': 322.315, 'pnl': -425.3399999999958}
# {'entry_time': Timestamp('2020-07-30 10:00:00'), 'exit_time': Timestamp('2020-07-30 10:34:00'), 'side': 'Short', 'entry_price': 319.94, 'exit_price': 321.27, 'pnl': -813.9599999999903}
# {'entry_time': Timestamp('2020-07-30 11:00:00'), 'exit_time': Timestamp('2020-07-30 11:00:00'), 'side': 'Short', 'entry_price': 321.18, 'exit_price': 321.18, 'pnl': 0.0}
#
# 日期: 2020-07-31  交易记录:
# {'entry_time': Timestamp('2020-07-31 10:00:00'), 'exit_time': Timestamp('2020-07-31 11:18:00'), 'side': 'Short', 'entry_price': 324.3201, 'exit_price': 324.224, 'pnl': 63.61820000002342}
# {'entry_time': Timestamp('2020-07-31 11:30:00'), 'exit_time': Timestamp('2020-07-31 11:30:00'), 'side': 'Short', 'entry_price': 324.115, 'exit_price': 324.115, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-07-31 12:00:00'), 'exit_time': Timestamp('2020-07-31 14:45:00'), 'side': 'Short', 'entry_price': 323.145, 'exit_price': 323.415, 'pnl': -178.7400000000256}
# {'entry_time': Timestamp('2020-07-31 15:00:00'), 'exit_time': Timestamp('2020-07-31 15:00:00'), 'side': 'Short', 'entry_price': 323.91, 'exit_price': 323.91, 'pnl': 0.0}
#
# 日期: 2020-08-03  交易记录:
# {'entry_time': Timestamp('2020-08-03 09:30:00'), 'exit_time': Timestamp('2020-08-03 09:34:00'), 'side': 'Long', 'entry_price': 328.13, 'exit_price': 328.09, 'pnl': -30.440000000015573}
# {'entry_time': Timestamp('2020-08-03 10:00:00'), 'exit_time': Timestamp('2020-08-03 10:43:00'), 'side': 'Long', 'entry_price': 328.77, 'exit_price': 328.43, 'pnl': -258.73999999998097}
# {'entry_time': Timestamp('2020-08-03 11:00:00'), 'exit_time': Timestamp('2020-08-03 11:00:00'), 'side': 'Long', 'entry_price': 328.38, 'exit_price': 328.38, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-08-03 11:30:00'), 'exit_time': Timestamp('2020-08-03 15:16:00'), 'side': 'Long', 'entry_price': 328.89, 'exit_price': 328.82, 'pnl': -53.26999999999481}
# {'entry_time': Timestamp('2020-08-03 15:30:00'), 'exit_time': Timestamp('2020-08-03 15:33:00'), 'side': 'Long', 'entry_price': 329.16, 'exit_price': 328.5, 'pnl': -502.26000000001903}
#
# 日期: 2020-08-04  交易记录:
#   无有效交易记录
#
# 日期: 2020-08-05  交易记录:
#   无有效交易记录
#
# 日期: 2020-08-06  交易记录:
# {'entry_time': Timestamp('2020-08-06 15:00:00'), 'exit_time': Timestamp('2020-08-06 15:01:00'), 'side': 'Long', 'entry_price': 334.06, 'exit_price': 333.93, 'pnl': -96.19999999999663}
#
# 日期: 2020-08-07  交易记录:
# {'entry_time': Timestamp('2020-08-07 09:30:00'), 'exit_time': Timestamp('2020-08-07 09:32:00'), 'side': 'Short', 'entry_price': 333.18, 'exit_price': 333.36, 'pnl': -145.4400000000055}
#
# 日期: 2020-08-10  交易记录:
# {'entry_time': Timestamp('2020-08-10 11:00:00'), 'exit_time': Timestamp('2020-08-10 11:01:00'), 'side': 'Short', 'entry_price': 333.14, 'exit_price': 333.47, 'pnl': -267.30000000003315}
#
# 日期: 2020-08-11  交易记录:
#   无有效交易记录
#
# 日期: 2020-08-12  交易记录:
# {'entry_time': Timestamp('2020-08-12 10:30:00'), 'exit_time': Timestamp('2020-08-12 13:18:00'), 'side': 'Long', 'entry_price': 337.29, 'exit_price': 336.67, 'pnl': -559.2400000000041}
# {'entry_time': Timestamp('2020-08-12 13:30:00'), 'exit_time': Timestamp('2020-08-12 13:30:00'), 'side': 'Long', 'entry_price': 336.76, 'exit_price': 336.76, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-08-12 14:00:00'), 'exit_time': Timestamp('2020-08-12 16:00:00'), 'side': 'Long', 'entry_price': 337.9413, 'exit_price': 337.05, 'pnl': -803.952600000001}
#
# 日期: 2020-08-13  交易记录:
# {'entry_time': Timestamp('2020-08-13 13:00:00'), 'exit_time': Timestamp('2020-08-13 13:01:00'), 'side': 'Long', 'entry_price': 338.24, 'exit_price': 338.18, 'pnl': -54.18000000000205}
#
# 日期: 2020-08-14  交易记录:
#   无有效交易记录
#
# 日期: 2020-08-17  交易记录:
#   无有效交易记录
#
# 日期: 2020-08-18  交易记录:
# {'entry_time': Timestamp('2020-08-18 10:30:00'), 'exit_time': Timestamp('2020-08-18 10:33:00'), 'side': 'Short', 'entry_price': 336.95, 'exit_price': 337.04, 'pnl': -94.32000000003336}
#
# 日期: 2020-08-19  交易记录:
#   无有效交易记录
#
# 日期: 2020-08-20  交易记录:
# {'entry_time': Timestamp('2020-08-20 09:30:00'), 'exit_time': Timestamp('2020-08-20 09:34:00'), 'side': 'Short', 'entry_price': 335.37, 'exit_price': 335.86, 'pnl': -486.57000000000903}
# {'entry_time': Timestamp('2020-08-20 10:30:00'), 'exit_time': Timestamp('2020-08-20 10:32:00'), 'side': 'Long', 'entry_price': 337.26, 'exit_price': 337.1686, 'pnl': -90.76019999996487}
# {'entry_time': Timestamp('2020-08-20 12:00:00'), 'exit_time': Timestamp('2020-08-20 12:48:00'), 'side': 'Long', 'entry_price': 337.66, 'exit_price': 337.38, 'pnl': -278.04000000002935}
# {'entry_time': Timestamp('2020-08-20 13:00:00'), 'exit_time': Timestamp('2020-08-20 13:06:00'), 'side': 'Long', 'entry_price': 337.39, 'exit_price': 337.245, 'pnl': -143.98499999998194}
# {'entry_time': Timestamp('2020-08-20 13:30:00'), 'exit_time': Timestamp('2020-08-20 17:07:00'), 'side': 'Long', 'entry_price': 337.58, 'exit_price': 338.31, 'pnl': 724.8900000000181}
#
# 日期: 2020-08-21  交易记录:
#   无有效交易记录
#
# 日期: 2020-08-24  交易记录:
# {'entry_time': Timestamp('2020-08-24 09:30:00'), 'exit_time': Timestamp('2020-08-24 09:31:00'), 'side': 'Long', 'entry_price': 342.19, 'exit_price': 342.05, 'pnl': -140.6999999999863}
# {'entry_time': Timestamp('2020-08-24 10:00:00'), 'exit_time': Timestamp('2020-08-24 10:00:00'), 'side': 'Long', 'entry_price': 341.67, 'exit_price': 341.67, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-08-24 10:30:00'), 'exit_time': Timestamp('2020-08-24 10:35:00'), 'side': 'Long', 'entry_price': 342.08, 'exit_price': 341.88, 'pnl': -200.99999999998857}
# {'entry_time': Timestamp('2020-08-24 12:00:00'), 'exit_time': Timestamp('2020-08-24 12:06:00'), 'side': 'Long', 'entry_price': 341.89, 'exit_price': 341.81, 'pnl': -80.399999999984}
#
# 日期: 2020-08-25  交易记录:
# {'entry_time': Timestamp('2020-08-25 10:30:00'), 'exit_time': Timestamp('2020-08-25 10:35:00'), 'side': 'Short', 'entry_price': 342.34, 'exit_price': 342.72, 'pnl': -375.8200000000517}
#
# 日期: 2020-08-26  交易记录:
# {'entry_time': Timestamp('2020-08-26 11:30:00'), 'exit_time': Timestamp('2020-08-26 19:59:00'), 'side': 'Long', 'entry_price': 345.48, 'exit_price': np.float64(347.77), 'pnl': np.float64(2109.0899999999665)}
#
# 日期: 2020-08-27  交易记录:
# {'entry_time': Timestamp('2020-08-27 09:30:00'), 'exit_time': Timestamp('2020-08-27 09:32:00'), 'side': 'Long', 'entry_price': 348.42, 'exit_price': 348.175, 'pnl': -226.6250000000042}
# {'entry_time': Timestamp('2020-08-27 10:00:00'), 'exit_time': Timestamp('2020-08-27 10:06:00'), 'side': 'Long', 'entry_price': 349.08, 'exit_price': 348.1212, 'pnl': -886.8899999999968}
# {'entry_time': Timestamp('2020-08-27 10:30:00'), 'exit_time': Timestamp('2020-08-27 11:31:00'), 'side': 'Long', 'entry_price': 349.33, 'exit_price': 348.585, 'pnl': -689.1250000000042}
# {'entry_time': Timestamp('2020-08-27 12:00:00'), 'exit_time': Timestamp('2020-08-27 12:16:00'), 'side': 'Long', 'entry_price': 349.321, 'exit_price': 348.73, 'pnl': -546.6750000000076}
# {'entry_time': Timestamp('2020-08-27 14:30:00'), 'exit_time': Timestamp('2020-08-27 15:05:00'), 'side': 'Long', 'entry_price': 349.3518, 'exit_price': 348.79, 'pnl': -519.6650000000047}
# {'entry_time': Timestamp('2020-08-27 15:30:00'), 'exit_time': Timestamp('2020-08-27 15:44:00'), 'side': 'Long', 'entry_price': 349.425, 'exit_price': 348.97, 'pnl': -420.8749999999853}
#
# 日期: 2020-08-28  交易记录:
# {'entry_time': Timestamp('2020-08-28 11:00:00'), 'exit_time': Timestamp('2020-08-28 11:02:00'), 'side': 'Short', 'entry_price': 348.32, 'exit_price': 348.53, 'pnl': -185.00999999998197}
#
# 日期: 2020-08-31  交易记录:
# {'entry_time': Timestamp('2020-08-31 10:00:00'), 'exit_time': Timestamp('2020-08-31 10:10:00'), 'side': 'Short', 'entry_price': 350.13, 'exit_price': 350.37, 'pnl': -234.9600000000089}
# {'entry_time': Timestamp('2020-08-31 11:30:00'), 'exit_time': Timestamp('2020-08-31 11:40:00'), 'side': 'Short', 'entry_price': 349.46, 'exit_price': 350.03, 'pnl': -558.0299999999934}
#
# 日期: 2020-09-01  交易记录:
#   无有效交易记录
#
# 日期: 2020-09-02  交易记录:
# {'entry_time': Timestamp('2020-09-02 12:30:00'), 'exit_time': Timestamp('2020-09-02 19:59:00'), 'side': 'Long', 'entry_price': 355.39, 'exit_price': np.float64(358.43), 'pnl': np.float64(2708.640000000018)}
#
# 日期: 2020-09-03  交易记录:
# {'entry_time': Timestamp('2020-09-03 09:30:00'), 'exit_time': Timestamp('2020-09-03 09:47:00'), 'side': 'Short', 'entry_price': 356.155, 'exit_price': 356.07, 'pnl': 31.704999999992367}
# {'entry_time': Timestamp('2020-09-03 10:00:00'), 'exit_time': Timestamp('2020-09-03 19:59:00'), 'side': 'Short', 'entry_price': 355.67, 'exit_price': np.float64(343.27), 'pnl': np.float64(4625.200000000013)}
#
# 日期: 2020-09-04  交易记录:
# {'entry_time': Timestamp('2020-09-04 10:30:00'), 'exit_time': Timestamp('2020-09-04 12:29:00'), 'side': 'Short', 'entry_price': 339.67, 'exit_price': 340.5, 'pnl': -323.6999999999938}
# {'entry_time': Timestamp('2020-09-04 12:30:00'), 'exit_time': Timestamp('2020-09-04 12:31:00'), 'side': 'Short', 'entry_price': 340.27, 'exit_price': 340.58, 'pnl': -120.90000000000089}
# {'entry_time': Timestamp('2020-09-04 13:00:00'), 'exit_time': Timestamp('2020-09-04 13:00:00'), 'side': 'Short', 'entry_price': 340.65, 'exit_price': 340.65, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-09-04 13:30:00'), 'exit_time': Timestamp('2020-09-04 13:48:00'), 'side': 'Short', 'entry_price': 338.89, 'exit_price': 340.35, 'pnl': -569.4000000000142}
# {'entry_time': Timestamp('2020-09-04 14:00:00'), 'exit_time': Timestamp('2020-09-04 14:00:00'), 'side': 'Short', 'entry_price': 340.75, 'exit_price': 340.75, 'pnl': 0.0}
#
# 日期: 2020-09-08  交易记录:
# {'entry_time': Timestamp('2020-09-08 09:30:00'), 'exit_time': Timestamp('2020-09-08 09:36:00'), 'side': 'Short', 'entry_price': 335.57, 'exit_price': 336.67, 'pnl': -366.30000000000757}
# {'entry_time': Timestamp('2020-09-08 10:00:00'), 'exit_time': Timestamp('2020-09-08 10:00:00'), 'side': 'Short', 'entry_price': 336.49, 'exit_price': 336.49, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-09-08 10:30:00'), 'exit_time': Timestamp('2020-09-08 10:30:00'), 'side': 'Short', 'entry_price': 337.73, 'exit_price': 337.73, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-09-08 11:00:00'), 'exit_time': Timestamp('2020-09-08 11:01:00'), 'side': 'Short', 'entry_price': 335.67, 'exit_price': 336.48, 'pnl': -269.73000000000076}
# {'entry_time': Timestamp('2020-09-08 11:30:00'), 'exit_time': Timestamp('2020-09-08 12:10:00'), 'side': 'Short', 'entry_price': 335.99, 'exit_price': 336.2, 'pnl': -69.92999999999319}
# {'entry_time': Timestamp('2020-09-08 12:30:00'), 'exit_time': Timestamp('2020-09-08 12:38:00'), 'side': 'Short', 'entry_price': 335.6, 'exit_price': 336.18, 'pnl': -193.1399999999947}
# {'entry_time': Timestamp('2020-09-08 13:00:00'), 'exit_time': Timestamp('2020-09-08 13:00:00'), 'side': 'Short', 'entry_price': 336.72, 'exit_price': 336.72, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-09-08 13:30:00'), 'exit_time': Timestamp('2020-09-08 13:30:00'), 'side': 'Short', 'entry_price': 337.03, 'exit_price': 337.03, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-09-08 14:00:00'), 'exit_time': Timestamp('2020-09-08 14:00:00'), 'side': 'Short', 'entry_price': 337.44, 'exit_price': 337.44, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-09-08 14:30:00'), 'exit_time': Timestamp('2020-09-08 19:59:00'), 'side': 'Short', 'entry_price': 335.28, 'exit_price': np.float64(332.3), 'pnl': np.float64(992.3399999999872)}
#
# 日期: 2020-09-09  交易记录:
# {'entry_time': Timestamp('2020-09-09 09:30:00'), 'exit_time': Timestamp('2020-09-09 09:38:00'), 'side': 'Long', 'entry_price': 337.7, 'exit_price': 336.98, 'pnl': -234.71999999999036}
# {'entry_time': Timestamp('2020-09-09 10:00:00'), 'exit_time': Timestamp('2020-09-09 15:58:00'), 'side': 'Long', 'entry_price': 338.49, 'exit_price': 339.97, 'pnl': 482.48000000000593}
#
# 日期: 2020-09-10  交易记录:
# {'entry_time': Timestamp('2020-09-10 14:30:00'), 'exit_time': Timestamp('2020-09-10 14:32:00'), 'side': 'Short', 'entry_price': 334.61, 'exit_price': 335.08, 'pnl': -152.7499999999904}
# {'entry_time': Timestamp('2020-09-10 15:30:00'), 'exit_time': Timestamp('2020-09-10 15:41:00'), 'side': 'Short', 'entry_price': 333.95, 'exit_price': 335.06, 'pnl': -360.75000000000443}
#
# 日期: 2020-09-11  交易记录:
# {'entry_time': Timestamp('2020-09-11 13:30:00'), 'exit_time': Timestamp('2020-09-11 13:35:00'), 'side': 'Short', 'entry_price': 331.56, 'exit_price': 331.8799, 'pnl': -104.60730000000598}
# {'entry_time': Timestamp('2020-09-11 14:00:00'), 'exit_time': Timestamp('2020-09-11 14:03:00'), 'side': 'Short', 'entry_price': 331.41, 'exit_price': 331.89, 'pnl': -156.95999999998736}
#
# 日期: 2020-09-14  交易记录:
#   无有效交易记录
#
# 日期: 2020-09-15  交易记录:
# {'entry_time': Timestamp('2020-09-15 09:30:00'), 'exit_time': Timestamp('2020-09-15 09:49:00'), 'side': 'Long', 'entry_price': 341.18, 'exit_price': 341.33, 'pnl': 48.74999999999261}
# {'entry_time': Timestamp('2020-09-15 10:00:00'), 'exit_time': Timestamp('2020-09-15 10:12:00'), 'side': 'Long', 'entry_price': 341.67, 'exit_price': 341.435, 'pnl': -76.37500000000443}
#
# 日期: 2020-09-16  交易记录:
#   无有效交易记录
#
# 日期: 2020-09-17  交易记录:
#   无有效交易记录
#
# 日期: 2020-09-18  交易记录:
# {'entry_time': Timestamp('2020-09-18 13:00:00'), 'exit_time': Timestamp('2020-09-18 15:10:00'), 'side': 'Short', 'entry_price': 330.88, 'exit_price': 330.995, 'pnl': -39.56000000000313}
#
# 日期: 2020-09-21  交易记录:
# {'entry_time': Timestamp('2020-09-21 09:30:00'), 'exit_time': Timestamp('2020-09-21 09:31:00'), 'side': 'Short', 'entry_price': 325.51, 'exit_price': 326.19, 'pnl': -237.32000000000238}
# {'entry_time': Timestamp('2020-09-21 10:00:00'), 'exit_time': Timestamp('2020-09-21 10:00:00'), 'side': 'Short', 'entry_price': 325.5, 'exit_price': 325.5, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-09-21 10:30:00'), 'exit_time': Timestamp('2020-09-21 11:57:00'), 'side': 'Short', 'entry_price': 322.56, 'exit_price': 323.71, 'pnl': -401.34999999999206}
# {'entry_time': Timestamp('2020-09-21 12:00:00'), 'exit_time': Timestamp('2020-09-21 12:00:00'), 'side': 'Short', 'entry_price': 323.7345, 'exit_price': 323.7345, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-09-21 12:30:00'), 'exit_time': Timestamp('2020-09-21 12:30:00'), 'side': 'Short', 'entry_price': 324.27, 'exit_price': 324.27, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-09-21 13:00:00'), 'exit_time': Timestamp('2020-09-21 13:13:00'), 'side': 'Short', 'entry_price': 323.3, 'exit_price': 323.69, 'pnl': -136.10999999999524}
# {'entry_time': Timestamp('2020-09-21 13:30:00'), 'exit_time': Timestamp('2020-09-21 13:30:00'), 'side': 'Short', 'entry_price': 324.38, 'exit_price': 324.38, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-09-21 14:00:00'), 'exit_time': Timestamp('2020-09-21 14:01:00'), 'side': 'Short', 'entry_price': 323.59, 'exit_price': 323.78, 'pnl': -66.3099999999992}
# {'entry_time': Timestamp('2020-09-21 14:30:00'), 'exit_time': Timestamp('2020-09-21 15:01:00'), 'side': 'Short', 'entry_price': 323.03, 'exit_price': 323.865, 'pnl': -291.4150000000127}
#
# 日期: 2020-09-22  交易记录:
#   无有效交易记录
#
# 日期: 2020-09-23  交易记录:
# {'entry_time': Timestamp('2020-09-23 14:30:00'), 'exit_time': Timestamp('2020-09-23 19:59:00'), 'side': 'Short', 'entry_price': 324.94, 'exit_price': np.float64(321.7), 'pnl': np.float64(1065.960000000003)}
#
# 日期: 2020-09-24  交易记录:
# {'entry_time': Timestamp('2020-09-24 13:30:00'), 'exit_time': Timestamp('2020-09-24 13:35:00'), 'side': 'Long', 'entry_price': 326.39, 'exit_price': 326.22, 'pnl': -69.18999999998334}
#
# 日期: 2020-09-25  交易记录:
# {'entry_time': Timestamp('2020-09-25 15:30:00'), 'exit_time': Timestamp('2020-09-25 15:34:00'), 'side': 'Long', 'entry_price': 329.0099, 'exit_price': 328.45, 'pnl': -220.04070000001076}
#
# 日期: 2020-09-28  交易记录:
# {'entry_time': Timestamp('2020-09-28 09:30:00'), 'exit_time': Timestamp('2020-09-28 09:37:00'), 'side': 'Long', 'entry_price': 333.32, 'exit_price': 333.04, 'pnl': -128.2399999999875}
# {'entry_time': Timestamp('2020-09-28 10:30:00'), 'exit_time': Timestamp('2020-09-28 10:48:00'), 'side': 'Long', 'entry_price': 334.22, 'exit_price': 333.25, 'pnl': -444.2600000000125}
# {'entry_time': Timestamp('2020-09-28 11:00:00'), 'exit_time': Timestamp('2020-09-28 11:00:00'), 'side': 'Long', 'entry_price': 333.14, 'exit_price': 333.14, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-09-28 11:30:00'), 'exit_time': Timestamp('2020-09-28 12:01:00'), 'side': 'Long', 'entry_price': 333.63, 'exit_price': 333.415, 'pnl': -98.46999999998854}
# {'entry_time': Timestamp('2020-09-28 12:30:00'), 'exit_time': Timestamp('2020-09-28 12:30:00'), 'side': 'Long', 'entry_price': 333.39, 'exit_price': 333.39, 'pnl': 0.0}
# {'entry_time': Timestamp('2020-09-28 13:00:00'), 'exit_time': Timestamp('2020-09-28 14:23:00'), 'side': 'Long', 'entry_price': 334.12, 'exit_price': 334.235, 'pnl': 52.670000000004165}
# {'entry_time': Timestamp('2020-09-28 14:30:00'), 'exit_time': Timestamp('2020-09-28 15:03:00'), 'side': 'Long', 'entry_price': 334.66, 'exit_price': 334.36, 'pnl': -137.4000000000052}
# {'entry_time': Timestamp('2020-09-28 15:30:00'), 'exit_time': Timestamp('2020-09-28 15:31:00'), 'side': 'Long', 'entry_price': 334.39, 'exit_price': 333.825, 'pnl': -258.76999999999896}
#
# 日期: 2020-09-29  交易记录:
# {'entry_time': Timestamp('2020-09-29 12:30:00'), 'exit_time': Timestamp('2020-09-29 12:33:00'), 'side': 'Short', 'entry_price': 332.13, 'exit_price': 332.2, 'pnl': -33.94999999999669}
#
# 日期: 2020-09-30  交易记录:
# {'entry_time': Timestamp('2020-09-30 10:00:00'), 'exit_time': Timestamp('2020-09-30 14:24:00'), 'side': 'Long', 'entry_price': 335.06, 'exit_price': 336.63, 'pnl': 734.7599999999968}
#
# 日期: 2020-10-01  交易记录:
#   无有效交易记录
#
# 日期: 2020-10-02  交易记录:
#   无有效交易记录
#
# 日期: 2020-10-05  交易记录:
# {'entry_time': Timestamp('2020-10-05 09:30:00'), 'exit_time': Timestamp('2020-10-05 09:56:00'), 'side': 'Long', 'entry_price': 336.442, 'exit_price': 336.53, 'pnl': 40.4799999999841}
# {'entry_time': Timestamp('2020-10-05 10:00:00'), 'exit_time': Timestamp('2020-10-05 13:48:00'), 'side': 'Long', 'entry_price': 336.87, 'exit_price': 338.0299, 'pnl': 533.5539999999969}
# {'entry_time': Timestamp('2020-10-05 15:00:00'), 'exit_time': Timestamp('2020-10-05 19:28:00'), 'side': 'Long', 'entry_price': 338.99, 'exit_price': 339.22, 'pnl': 105.80000000000837}
#
# 日期: 2020-10-06  交易记录:
#   无有效交易记录
#
# 日期: 2020-10-07  交易记录:
# {'entry_time': Timestamp('2020-10-07 10:00:00'), 'exit_time': Timestamp('2020-10-07 10:03:00'), 'side': 'Long', 'entry_price': 338.88, 'exit_price': 338.74, 'pnl': -60.75999999999408}
# {'entry_time': Timestamp('2020-10-07 10:30:00'), 'exit_time': Timestamp('2020-10-07 10:35:00'), 'side': 'Long', 'entry_price': 339.7, 'exit_price': 339.4999, 'pnl': -86.84339999998417}
# {'entry_time': Timestamp('2020-10-07 11:00:00'), 'exit_time': Timestamp('2020-10-07 11:15:00'), 'side': 'Long', 'entry_price': 339.39, 'exit_price': 339.44, 'pnl': 21.700000000004934}
# {'entry_time': Timestamp('2020-10-07 11:30:00'), 'exit_time': Timestamp('2020-10-07 11:31:00'), 'side': 'Long', 'entry_price': 339.58, 'exit_price': 339.43, 'pnl': -65.09999999999013}
# {'entry_time': Timestamp('2020-10-07 14:30:00'), 'exit_time': Timestamp('2020-10-07 15:59:00'), 'side': 'Long', 'entry_price': 341.14, 'exit_price': 340.73, 'pnl': -177.93999999998618}
#
# 日期: 2020-10-08  交易记录:
#   无有效交易记录
#
# 日期: 2020-10-09  交易记录:
#   无有效交易记录
#
# 日期: 2020-10-12  交易记录:
# {'entry_time': Timestamp('2020-10-12 09:30:00'), 'exit_time': Timestamp('2020-10-12 09:31:00'), 'side': 'Long', 'entry_price': 349.395, 'exit_price': 349.15, 'pnl': -104.37000000000194}
# {'entry_time': Timestamp('2020-10-12 10:00:00'), 'exit_time': Timestamp('2020-10-12 16:25:00'), 'side': 'Long', 'entry_price': 349.35, 'exit_price': 346.7752, 'pnl': -1096.8648000000167}
#
# 日期: 2020-10-13  交易记录:
#   无有效交易记录
#
# 日期: 2020-10-14  交易记录:
# {'entry_time': Timestamp('2020-10-14 12:00:00'), 'exit_time': Timestamp('2020-10-14 12:05:00'), 'side': 'Short', 'entry_price': 348.32, 'exit_price': 348.78, 'pnl': -252.99999999998875}
# {'entry_time': Timestamp('2020-10-14 12:30:00'), 'exit_time': Timestamp('2020-10-14 13:01:00'), 'side': 'Short', 'entry_price': 347.69, 'exit_price': 348.34, 'pnl': -357.4999999999875}
# {'entry_time': Timestamp('2020-10-14 13:30:00'), 'exit_time': Timestamp('2020-10-14 13:49:00'), 'side': 'Short', 'entry_price': 347.71, 'exit_price': 348.055, 'pnl': -189.750000000015}
#
# 日期: 2020-10-15  交易记录:
# ...
# {'entry_time': Timestamp('2025-02-20 13:00:00'), 'exit_time': Timestamp('2025-02-20 14:01:00'), 'side': 'Short', 'entry_price': 608.09, 'exit_price': 608.79, 'pnl': -566.2999999999448}
#
# 日期: 2025-02-21  交易记录:
# {'entry_time': Timestamp('2025-02-21 10:00:00'), 'exit_time': Timestamp('2025-02-21 10:10:00'), 'side': 'Short', 'entry_price': 608.18, 'exit_price': 608.4112, 'pnl': -166.00160000004166}
# {'entry_time': Timestamp('2025-02-21 10:30:00'), 'exit_time': Timestamp('2025-02-21 19:59:00'), 'side': 'Short', 'entry_price': 606.89, 'exit_price': np.float64(600.24), 'pnl': np.float64(4774.699999999983)}
#
# 日期: 2025-02-24  交易记录:
#   无有效交易记录
#
# 日期: 2025-02-25  交易记录:
# {'entry_time': Timestamp('2025-02-25 10:00:00'), 'exit_time': Timestamp('2025-02-25 11:57:00'), 'side': 'Short', 'entry_price': 594.125, 'exit_price': 593.64, 'pnl': 389.45500000001095}
# {'entry_time': Timestamp('2025-02-25 12:00:00'), 'exit_time': Timestamp('2025-02-25 12:00:00'), 'side': 'Short', 'entry_price': 593.32, 'exit_price': 593.32, 'pnl': 0.0}
# {'entry_time': Timestamp('2025-02-25 12:30:00'), 'exit_time': Timestamp('2025-02-25 12:30:00'), 'side': 'Short', 'entry_price': 593.55, 'exit_price': 593.55, 'pnl': 0.0}
# {'entry_time': Timestamp('2025-02-25 13:30:00'), 'exit_time': Timestamp('2025-02-25 13:30:00'), 'side': 'Short', 'entry_price': 593.69, 'exit_price': 593.69, 'pnl': 0.0}
#
# 日期: 2025-02-26  交易记录:
# {'entry_time': Timestamp('2025-02-26 12:30:00'), 'exit_time': Timestamp('2025-02-26 12:31:00'), 'side': 'Long', 'entry_price': 598.6743, 'exit_price': 598.39, 'pnl': -249.04680000002645}
# {'entry_time': Timestamp('2025-02-26 14:00:00'), 'exit_time': Timestamp('2025-02-26 14:20:00'), 'side': 'Short', 'entry_price': 592.46, 'exit_price': 593.34, 'pnl': -770.879999999996}
# {'entry_time': Timestamp('2025-02-26 15:00:00'), 'exit_time': Timestamp('2025-02-26 15:06:00'), 'side': 'Short', 'entry_price': 592.79, 'exit_price': 593.3, 'pnl': -446.75999999999203}
#
# 日期: 2025-02-27  交易记录:
# {'entry_time': Timestamp('2025-02-27 10:00:00'), 'exit_time': Timestamp('2025-02-27 10:02:00'), 'side': 'Short', 'entry_price': 591.2, 'exit_price': 591.648, 'pnl': -302.84799999998586}
# {'entry_time': Timestamp('2025-02-27 14:30:00'), 'exit_time': Timestamp('2025-02-27 19:59:00'), 'side': 'Short', 'entry_price': 590.23, 'exit_price': np.float64(584.89), 'pnl': np.float64(3609.8400000000215)}
#
# 日期: 2025-02-28  交易记录:
#   无有效交易记录
#
# 日期: 2025-03-03  交易记录:
# {'entry_time': Timestamp('2025-03-03 09:30:00'), 'exit_time': Timestamp('2025-03-03 09:30:00'), 'side': 'Long', 'entry_price': 595.871, 'exit_price': 595.871, 'pnl': 0.0}
# {'entry_time': Timestamp('2025-03-03 13:00:00'), 'exit_time': Timestamp('2025-03-03 19:59:00'), 'side': 'Short', 'entry_price': 591.55, 'exit_price': np.float64(585.4), 'pnl': np.float64(3640.7999999999865)}
#
# 日期: 2025-03-04  交易记录:
# {'entry_time': Timestamp('2025-03-04 09:30:00'), 'exit_time': Timestamp('2025-03-04 09:37:00'), 'side': 'Short', 'entry_price': 579.44, 'exit_price': 579.79, 'pnl': -216.6499999999437}
# {'entry_time': Timestamp('2025-03-04 10:00:00'), 'exit_time': Timestamp('2025-03-04 11:53:00'), 'side': 'Short', 'entry_price': 575.23, 'exit_price': 576.245, 'pnl': -628.2849999999916}
# {'entry_time': Timestamp('2025-03-04 12:00:00'), 'exit_time': Timestamp('2025-03-04 12:02:00'), 'side': 'Short', 'entry_price': 575.89, 'exit_price': 576.03, 'pnl': -86.65999999999156}
# {'entry_time': Timestamp('2025-03-04 12:30:00'), 'exit_time': Timestamp('2025-03-04 12:30:00'), 'side': 'Short', 'entry_price': 577.4, 'exit_price': 577.4, 'pnl': 0.0}
# {'entry_time': Timestamp('2025-03-04 13:00:00'), 'exit_time': Timestamp('2025-03-04 13:00:00'), 'side': 'Short', 'entry_price': 576.65, 'exit_price': 576.65, 'pnl': 0.0}
# {'entry_time': Timestamp('2025-03-04 13:30:00'), 'exit_time': Timestamp('2025-03-04 13:30:00'), 'side': 'Short', 'entry_price': 577.13, 'exit_price': 577.13, 'pnl': 0.0}
# {'entry_time': Timestamp('2025-03-04 14:00:00'), 'exit_time': Timestamp('2025-03-04 14:00:00'), 'side': 'Short', 'entry_price': 580.43, 'exit_price': 580.43, 'pnl': 0.0}
#
# 日期: 2025-03-05  交易记录:
# {'entry_time': Timestamp('2025-03-05 09:30:00'), 'exit_time': Timestamp('2025-03-05 09:39:00'), 'side': 'Short', 'entry_price': 577.3, 'exit_price': 577.64, 'pnl': -209.10000000001958}
# {'entry_time': Timestamp('2025-03-05 10:30:00'), 'exit_time': Timestamp('2025-03-05 10:38:00'), 'side': 'Short', 'entry_price': 575.8, 'exit_price': 577.66, 'pnl': -1143.9000000000083}
# {'entry_time': Timestamp('2025-03-05 11:00:00'), 'exit_time': Timestamp('2025-03-05 12:00:00'), 'side': 'Short', 'entry_price': 576.26, 'exit_price': 577.27, 'pnl': -621.1499999999944}
#
# 日期: 2025-03-06  交易记录:
# {'entry_time': Timestamp('2025-03-06 09:30:00'), 'exit_time': Timestamp('2025-03-06 09:50:00'), 'side': 'Short', 'entry_price': 575.5, 'exit_price': 575.51, 'pnl': -6.569999999994025}
# {'entry_time': Timestamp('2025-03-06 10:00:00'), 'exit_time': Timestamp('2025-03-06 10:03:00'), 'side': 'Short', 'entry_price': 574.99, 'exit_price': 576.06, 'pnl': -702.9899999999582}
# {'entry_time': Timestamp('2025-03-06 10:30:00'), 'exit_time': Timestamp('2025-03-06 10:30:00'), 'side': 'Short', 'entry_price': 578.32, 'exit_price': 578.32, 'pnl': 0.0}
# {'entry_time': Timestamp('2025-03-06 12:00:00'), 'exit_time': Timestamp('2025-03-06 14:52:00'), 'side': 'Short', 'entry_price': 574.7, 'exit_price': 574.81, 'pnl': -72.26999999993427}
# {'entry_time': Timestamp('2025-03-06 15:00:00'), 'exit_time': Timestamp('2025-03-06 16:15:00'), 'side': 'Short', 'entry_price': 571.44, 'exit_price': 574.68, 'pnl': -2128.679999999931}
#
# 日期: 2025-03-07  交易记录:
# {'entry_time': Timestamp('2025-03-07 09:30:00'), 'exit_time': Timestamp('2025-03-07 09:33:00'), 'side': 'Short', 'entry_price': 571.68, 'exit_price': 572.44, 'pnl': -494.7600000000681}
# {'entry_time': Timestamp('2025-03-07 11:00:00'), 'exit_time': Timestamp('2025-03-07 12:43:00'), 'side': 'Short', 'entry_price': 570.73, 'exit_price': 570.8394, 'pnl': -71.21939999995891}
# {'entry_time': Timestamp('2025-03-07 13:00:00'), 'exit_time': Timestamp('2025-03-07 13:01:00'), 'side': 'Short', 'entry_price': 570.38, 'exit_price': 570.65, 'pnl': -175.76999999998816}
#
# 日期: 2025-03-10  交易记录:
# {'entry_time': Timestamp('2025-03-10 09:30:00'), 'exit_time': Timestamp('2025-03-10 09:31:00'), 'side': 'Short', 'entry_price': 568.26, 'exit_price': 568.6339, 'pnl': -214.61860000002798}
# {'entry_time': Timestamp('2025-03-10 10:00:00'), 'exit_time': Timestamp('2025-03-10 11:36:00'), 'side': 'Short', 'entry_price': 567.11, 'exit_price': 566.27, 'pnl': 482.1600000000183}
# {'entry_time': Timestamp('2025-03-10 12:00:00'), 'exit_time': Timestamp('2025-03-10 19:59:00'), 'side': 'Short', 'entry_price': 564.02, 'exit_price': np.float64(558.58), 'pnl': np.float64(3122.559999999966)}
#
# 日期: 2025-03-11  交易记录:
# {'entry_time': Timestamp('2025-03-11 13:00:00'), 'exit_time': Timestamp('2025-03-11 13:45:00'), 'side': 'Short', 'entry_price': 554.0, 'exit_price': 554.19, 'pnl': -115.90000000003329}
#
# 日期: 2025-03-12  交易记录:
# {'entry_time': Timestamp('2025-03-12 09:30:00'), 'exit_time': Timestamp('2025-03-12 09:30:00'), 'side': 'Long', 'entry_price': 562.0197, 'exit_price': 562.0197, 'pnl': 0.0}
#
# 日期: 2025-03-13  交易记录:
# {'entry_time': Timestamp('2025-03-13 12:00:00'), 'exit_time': Timestamp('2025-03-13 12:02:00'), 'side': 'Short', 'entry_price': 552.55, 'exit_price': 552.83, 'pnl': -172.48000000005322}
# {'entry_time': Timestamp('2025-03-13 13:00:00'), 'exit_time': Timestamp('2025-03-13 13:04:00'), 'side': 'Short', 'entry_price': 552.6999, 'exit_price': 552.88, 'pnl': -110.94160000002375}
# {'entry_time': Timestamp('2025-03-13 13:30:00'), 'exit_time': Timestamp('2025-03-13 14:10:00'), 'side': 'Short', 'entry_price': 550.89, 'exit_price': 552.2, 'pnl': -806.9600000000364}
# {'entry_time': Timestamp('2025-03-13 15:30:00'), 'exit_time': Timestamp('2025-03-13 15:33:00'), 'side': 'Short', 'entry_price': 551.06, 'exit_price': 551.98, 'pnl': -566.7200000000448}
#
# 日期: 2025-03-14  交易记录:
# {'entry_time': Timestamp('2025-03-14 11:00:00'), 'exit_time': Timestamp('2025-03-14 19:59:00'), 'side': 'Long', 'entry_price': 560.33, 'exit_price': np.float64(562.08), 'pnl': np.float64(957.25)}
#
# 日期: 2025-03-17  交易记录:
# {'entry_time': Timestamp('2025-03-17 10:00:00'), 'exit_time': Timestamp('2025-03-17 10:01:00'), 'side': 'Long', 'entry_price': 565.67, 'exit_price': 564.94, 'pnl': -369.3799999999517}
# {'entry_time': Timestamp('2025-03-17 14:00:00'), 'exit_time': Timestamp('2025-03-17 15:52:00'), 'side': 'Long', 'entry_price': 567.7099, 'exit_price': 568.3, 'pnl': 298.5906000000034}
#
# 日期: 2025-03-18  交易记录:
# {'entry_time': Timestamp('2025-03-18 10:00:00'), 'exit_time': Timestamp('2025-03-18 12:12:00'), 'side': 'Short', 'entry_price': 560.37, 'exit_price': 560.95, 'pnl': -288.8400000000204}
# {'entry_time': Timestamp('2025-03-18 12:30:00'), 'exit_time': Timestamp('2025-03-18 12:32:00'), 'side': 'Short', 'entry_price': 561.34, 'exit_price': 561.68, 'pnl': -169.31999999995924}
# {'entry_time': Timestamp('2025-03-18 13:00:00'), 'exit_time': Timestamp('2025-03-18 13:13:00'), 'side': 'Short', 'entry_price': 560.94, 'exit_price': 561.0198, 'pnl': -39.74039999998877}
# {'entry_time': Timestamp('2025-03-18 13:30:00'), 'exit_time': Timestamp('2025-03-18 13:31:00'), 'side': 'Short', 'entry_price': 560.29, 'exit_price': 560.68, 'pnl': -194.2199999999932}
# {'entry_time': Timestamp('2025-03-18 14:00:00'), 'exit_time': Timestamp('2025-03-18 14:21:00'), 'side': 'Short', 'entry_price': 560.905, 'exit_price': 560.89, 'pnl': 7.469999999993206}
#
# 日期: 2025-03-19  交易记录:
# {'entry_time': Timestamp('2025-03-19 15:00:00'), 'exit_time': Timestamp('2025-03-19 15:26:00'), 'side': 'Long', 'entry_price': 568.68, 'exit_price': 567.76, 'pnl': -477.47999999997876}
# {'entry_time': Timestamp('2025-03-19 15:30:00'), 'exit_time': Timestamp('2025-03-19 15:31:00'), 'side': 'Long', 'entry_price': 567.67, 'exit_price': 567.48, 'pnl': -98.60999999996932}
#
# 日期: 2025-03-20  交易记录:
# {'entry_time': Timestamp('2025-03-20 09:30:00'), 'exit_time': Timestamp('2025-03-20 09:33:00'), 'side': 'Short', 'entry_price': 562.9302, 'exit_price': 564.5, 'pnl': -864.9597999999926}
#
# 日期: 2025-03-21  交易记录:
# {'entry_time': Timestamp('2025-03-21 09:30:00'), 'exit_time': Timestamp('2025-03-21 09:33:00'), 'side': 'Short', 'entry_price': 559.88, 'exit_price': 559.75, 'pnl': 74.74999999999739}
# {'entry_time': Timestamp('2025-03-21 10:00:00'), 'exit_time': Timestamp('2025-03-21 10:18:00'), 'side': 'Short', 'entry_price': 559.585, 'exit_price': 559.32, 'pnl': 152.37499999999216}
#
# 日期: 2025-03-24  交易记录:
# {'entry_time': Timestamp('2025-03-24 10:00:00'), 'exit_time': Timestamp('2025-03-24 12:29:00'), 'side': 'Long', 'entry_price': 572.6075, 'exit_price': 573.25, 'pnl': 357.8725000000228}
# {'entry_time': Timestamp('2025-03-24 12:30:00'), 'exit_time': Timestamp('2025-03-24 13:02:00'), 'side': 'Long', 'entry_price': 573.29, 'exit_price': 572.94, 'pnl': -194.94999999994934}
# {'entry_time': Timestamp('2025-03-24 14:00:00'), 'exit_time': Timestamp('2025-03-24 14:01:00'), 'side': 'Long', 'entry_price': 573.03, 'exit_price': 572.69, 'pnl': -189.3799999999544}
# {'entry_time': Timestamp('2025-03-24 15:00:00'), 'exit_time': Timestamp('2025-03-24 15:09:00'), 'side': 'Long', 'entry_price': 573.605, 'exit_price': 573.88, 'pnl': 153.17499999998734}
# {'entry_time': Timestamp('2025-03-24 15:30:00'), 'exit_time': Timestamp('2025-03-24 18:12:00'), 'side': 'Long', 'entry_price': 573.86, 'exit_price': 573.86, 'pnl': 0.0}
#
# 日期: 2025-03-25  交易记录:
#   无有效交易记录
#
# 日期: 2025-03-26  交易记录:
# {'entry_time': Timestamp('2025-03-26 12:00:00'), 'exit_time': Timestamp('2025-03-26 12:01:00'), 'side': 'Short', 'entry_price': 570.62, 'exit_price': 570.68, 'pnl': -32.639999999970314}
# {'entry_time': Timestamp('2025-03-26 13:00:00'), 'exit_time': Timestamp('2025-03-26 19:59:00'), 'side': 'Short', 'entry_price': 569.61, 'exit_price': np.float64(567.62), 'pnl': np.float64(1082.560000000005)}
#
# 日期: 2025-03-27  交易记录:
#   无有效交易记录
#
# 日期: 2025-03-28  交易记录:
# {'entry_time': Timestamp('2025-03-28 10:00:00'), 'exit_time': Timestamp('2025-03-28 10:02:00'), 'side': 'Short', 'entry_price': 563.875, 'exit_price': 564.12, 'pnl': -141.85500000000263}
# {'entry_time': Timestamp('2025-03-28 10:30:00'), 'exit_time': Timestamp('2025-03-28 19:59:00'), 'side': 'Short', 'entry_price': 559.9576, 'exit_price': np.float64(554.15), 'pnl': np.float64(3362.600399999988)}
#
# 日期: 2025-03-31  交易记录:
# {'entry_time': Timestamp('2025-03-31 09:30:00'), 'exit_time': Timestamp('2025-03-31 09:53:00'), 'side': 'Short', 'entry_price': 550.122, 'exit_price': 549.155, 'pnl': 584.0679999999907}
#
# 日期: 2025-04-01  交易记录:
# {'entry_time': Timestamp('2025-04-01 12:00:00'), 'exit_time': Timestamp('2025-04-01 12:27:00'), 'side': 'Long', 'entry_price': 561.46, 'exit_price': 561.27, 'pnl': -112.86000000003241}
#
# 日期: 2025-04-02  交易记录:
# {'entry_time': Timestamp('2025-04-02 09:30:00'), 'exit_time': Timestamp('2025-04-02 09:33:00'), 'side': 'Short', 'entry_price': 555.06, 'exit_price': 556.79, 'pnl': -844.2400000000089}
# {'entry_time': Timestamp('2025-04-02 13:00:00'), 'exit_time': Timestamp('2025-04-02 13:01:00'), 'side': 'Long', 'entry_price': 565.88, 'exit_price': 565.84, 'pnl': -19.519999999982247}
#
# 日期: 2025-04-03  交易记录:
# {'entry_time': Timestamp('2025-04-03 11:00:00'), 'exit_time': Timestamp('2025-04-03 11:11:00'), 'side': 'Short', 'entry_price': 540.53, 'exit_price': 541.54, 'pnl': -484.79999999999563}
# {'entry_time': Timestamp('2025-04-03 14:30:00'), 'exit_time': Timestamp('2025-04-03 14:33:00'), 'side': 'Short', 'entry_price': 540.49, 'exit_price': 540.85, 'pnl': -172.80000000000655}
# {'entry_time': Timestamp('2025-04-03 15:30:00'), 'exit_time': Timestamp('2025-04-03 19:59:00'), 'side': 'Short', 'entry_price': 538.59, 'exit_price': np.float64(536.38), 'pnl': np.float64(1060.8000000000175)}
#
# 日期: 2025-04-04  交易记录:
# {'entry_time': Timestamp('2025-04-04 09:30:00'), 'exit_time': Timestamp('2025-04-04 09:30:00'), 'side': 'Short', 'entry_price': 524.76, 'exit_price': 524.76, 'pnl': 0.0}
# {'entry_time': Timestamp('2025-04-04 10:00:00'), 'exit_time': Timestamp('2025-04-04 11:04:00'), 'side': 'Short', 'entry_price': 522.48, 'exit_price': 520.3499, 'pnl': 751.9252999999895}
# {'entry_time': Timestamp('2025-04-04 11:30:00'), 'exit_time': Timestamp('2025-04-04 19:59:00'), 'side': 'Short', 'entry_price': 517.09, 'exit_price': np.float64(505.5), 'pnl': np.float64(4091.2700000000114)}
#
# 每个月累计收益率:
#             month_start    month_end  monthly_return
# Date
# 2020-04-30  100000.0000   98258.5403       -0.017415
# 2020-05-31   98258.5403   94827.7504       -0.034916
# 2020-06-30   94501.5904   94443.0759       -0.000619
# 2020-07-31   94383.3057   91403.8491       -0.031568
# 2020-08-31   90559.1391   85307.3563       -0.057993
# ...                 ...          ...             ...
# 2024-12-31  165987.8469  174379.9473        0.050559
# 2025-01-31  173189.8731  170096.8235       -0.017859
# 2025-02-28  170096.8235  174168.7510        0.023939
# 2025-03-31  177809.5510  176837.9827       -0.005464
# 2025-04-30  176725.1227  181107.7580        0.024799
#
# [61 rows x 3 columns]
#
# 每年累计收益率:
#              year_start     year_end  yearly_return
# Date
# 2020-12-31  100000.0000   87996.3994      -0.120036
# 2021-12-31   90562.7094  108625.5375       0.199451
# 2022-12-31  108625.5375  129631.9923       0.193384
# 2023-12-31  128305.1227  135544.9095       0.056426
# 2024-12-31  135039.0189  174379.9473       0.291330
# 2025-12-31  173189.8731  181107.7580       0.045718
#
# 整个回测期间累计收益率: 81.11%
# /var/folders/rq/lg6_61n50bb12byh9g0vdc380000gq/T/ipykernel_12012/3691695736.py:236: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly = daily_df.resample('M').agg({'capital': ['first', 'last']})
# /var/folders/rq/lg6_61n50bb12byh9g0vdc380000gq/T/ipykernel_12012/3691695736.py:240: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   yearly = daily_df.resample('A').agg({'capital': ['first', 'last']})
